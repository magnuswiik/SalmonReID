# %% [markdown]
# # Code for Salmon detection

# %%
# Cleaning the dataset

import os
import json
import numpy as np

root = "/Users/magnuswiik/prosjektoppgave_data/transfer_300774_files_a22bc256/Ide4_OpenClosedTransport/GP020101_rotated-annoterte-test"

annots = list(sorted(os.listdir(os.path.join(root, "Boxes"))))
imgs = list(sorted(os.listdir(os.path.join(root, "Images"))))

numbers = []

for annot in annots:
    number = annot[:-5]
    numbers.append(number)
    
    if annot[-4:] != "json":
        path = root + "/Boxes/" + annot
        print("Not a json file", path)
        os.remove(root + "/Boxes/" + annot)
        
    annots_path = os.path.join(root, "Boxes", annot)
    shapes = json.load(open(annots_path))['shapes']
    
    if len(shapes) == 0:
        path = root + "/Boxes/" + annot
        os.remove(root + "/Boxes/" + annot)


# Removes redundant images, so the number of jsons equal the number of imgs

for file in imgs:
    name = file[:-4]
    if name not in numbers:
        path = root + "/Images/" + file
        os.remove(root + "/Images/" + file)

# %% [markdown]
# # SalmonData set uses only the label '1' to signalize a Salmon. This is for Salmon detection task

# %%
import os
import json
import torch

from torchvision.io import read_image
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
import numpy as np


class SalmonDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms=None):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        
        self.imgs = list(sorted(os.listdir(os.path.join(root, "Images"))))
        self.annots = list(sorted(os.listdir(os.path.join(root, "Boxes"))))
    
    def __getitem__(self, idx):
        # load images and masks
        img_path = os.path.join(self.root, "Images", self.imgs[idx])
        annots_path = os.path.join(self.root, "Boxes", self.annots[idx])
        
        img = read_image(img_path)
        if "DS" not in annots_path:
            try:
                shapes = json.load(open(annots_path))['shapes']
            except:
                print("Cannot open json file...")
            
        boxes = [shape['points'] for shape in shapes]
        boxes_flattened = []
        for box in boxes:
            box = np.array(box).flatten().tolist()
            boxes_flattened.append(box)
        
        boxes_flattened = torch.tensor(boxes_flattened, dtype=torch.float)
        

        # Number of boxes in image
        num_objs = len(boxes_flattened)

        # there is only one class -> Salmon = 1
        labels = torch.ones((num_objs,), dtype=torch.int64)

        # Wrap sample and targets into torchvision tv_tensors:
        img = tv_tensors.Image(img)
        img = img.float() / 255.0
        

        target = {}
        target["boxes"] = boxes_flattened
        target["labels"] = labels
        target["image_id"] = idx
        target["area"] = (boxes_flattened[:,2]-boxes_flattened[:,0])*(boxes_flattened[:,3]-boxes_flattened[:,1])
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)

        if self.transforms is not None:
            img, target = self.transforms(img, target)
            
        if target["boxes"].numel() == 0:
            print("No boxes :(")

        return img, target

    def __len__(self):
        return len(self.imgs)

# %% [markdown]
# # SalmonIndividualsDataset uses group_id as label to facilitate the making of a individual reidentification dataset

# %%
import os
import json
import torch

from torchvision.io import read_image
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F
import numpy as np


class SalmonIndividualsDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms=None):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        
        self.imgs = list(sorted(os.listdir(os.path.join(root, "Images"))))
        self.annots = list(sorted(os.listdir(os.path.join(root, "Boxes"))))
    
    def __getitem__(self, idx):
        # load images and masks
        img_path = os.path.join(self.root, "Images", self.imgs[idx])
        annots_path = os.path.join(self.root, "Boxes", self.annots[idx])
        
        img = read_image(img_path)
        if "DS" not in annots_path:
            try:
                shapes = json.load(open(annots_path))['shapes']
            except:
                print("Cannot open json file...")
            
        
        boxes = []
        labels = []
        
        for shape in shapes:
            if shape['group_id'] is not None:
                labels.append(shape['group_id'])
                boxes.append(shape['points'])
                
        
        boxes_flattened = []
        for box in boxes:
            box = np.array(box).flatten().tolist()
            boxes_flattened.append(box)
        
        boxes_flattened = torch.tensor(boxes_flattened, dtype=torch.float)
        
        if boxes_flattened.ndim == 1:
            # Remove file that have no fish annotated
            os.remove(img_path)
            os.remove(annots_path)
        

        # Number of boxes in image
        num_objs = len(boxes_flattened)

        # there is only one class -> Salmon = 1
        labels = torch.tensor(labels, dtype=torch.int64)

        # Wrap sample and targets into torchvision tv_tensors:
        img = tv_tensors.Image(img)
        img = img.float() / 255.0

        target = {}
        target["boxes"] = boxes_flattened
        target["labels"] = labels
        target["image_id"] = idx
        target["area"] = (boxes_flattened[:,2]-boxes_flattened[:,0])*(boxes_flattened[:,3]-boxes_flattened[:,1])
        target["iscrowd"] = torch.zeros((num_objs,), dtype=torch.int64)

        if self.transforms is not None:
            img, target = self.transforms(img, target)
            
        if target["boxes"].numel() == 0:
            print("No boxes :(")

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor, FasterRCNN_ResNet50_FPN_Weights

def get_detection_model(num_classes, weights=FasterRCNN_ResNet50_FPN_Weights):
    # load a model pre-trained on COCO
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights=weights)

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
    
    return model

# %%
"""os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py")"""
# Out:
# 'os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py")\nos.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py")\nos.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py")\nos.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py")\nos.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py")'

# %% [markdown]
# # Assign indices to training, validation and test that takes datasources into consideration

# %%
# Split datasources equally into training, validation and test sets

import torch
import random

# Random seeds for reproducibility
g = torch.manual_seed(0)
random.seed(0)

data_path = "/Users/magnuswiik/prosjektoppgave_data/Masteroppgave_data/Christian_Annotert_Deteksjonssett/"

imgs = SalmonDataset(data_path).imgs

sourceindices = {'out1':0,
           'trigger21_out2':0,
           'smoltrecording_out2':0,
           'BIORACER':0,
           'Hero4':0,
           'OpenTransport':0}

for img in imgs:
    if 'out1' in img:
        sourceindices['out1'] = imgs.index(img)
    elif 'trigger21_out2'in img:
        sourceindices['trigger21_out2'] = imgs.index(img)
    elif 'smoltrecording_out2' in img:
        sourceindices['smoltrecording_out2'] = imgs.index(img)
    elif 'BIORACER' in img:
        sourceindices['BIORACER'] = imgs.index(img)
    elif 'Hero4' in img:
        sourceindices['Hero4'] = imgs.index(img)
    elif 'OpenTransport' in img:
        sourceindices['OpenTransport'] = imgs.index(img)
    else:
        print('A file is not counted!')

# Generate indices for each datasource      
sourceindices['out1'] = list(range(0,sourceindices['out1']))
sourceindices['trigger21_out2'] = list(range(sourceindices['out1'][-1], sourceindices['trigger21_out2']))
sourceindices['smoltrecording_out2'] = list(range(sourceindices['trigger21_out2'][-1], sourceindices['smoltrecording_out2']))
sourceindices['BIORACER'] = list(range(sourceindices['smoltrecording_out2'][-1], sourceindices['BIORACER']))
sourceindices['Hero4'] = list(range(sourceindices['BIORACER'][-1], sourceindices['Hero4']))
sourceindices['OpenTransport'] = list(range(sourceindices['Hero4'][-1], sourceindices['OpenTransport']))

indices_test = []
indices_validation = []
indices_training = []

# Distribute indices to each set by random sampling in a non-overlapping way
for source in sourceindices:
    indices_test += random.sample(sourceindices[source], int(len(sourceindices[source])*0.2))
    sourceindices[source] = [idx for idx in sourceindices[source] if idx not in indices_test]
    indices_validation += random.sample(sourceindices[source], int(len(sourceindices[source])*0.2))
    sourceindices[source] = [idx for idx in sourceindices[source] if idx not in indices_validation]
    indices_training += sourceindices[source]
    
# Shuffle once more to eradicate any sytematic trend in each set
random.shuffle(indices_test)
random.shuffle(indices_validation)
random.shuffle(indices_training)

# use our dataset and defined transformations
dataset = SalmonDataset(data_path)
dataset_validation = SalmonDataset(data_path)
dataset_test = SalmonDataset(data_path)

# split the dataset in train and test set
dataset_training = torch.utils.data.Subset(dataset, indices_training) # 80% for training and validation
dataset_validation = torch.utils.data.Subset(dataset_validation, indices_validation)
dataset_test = torch.utils.data.Subset(dataset_test, indices_test) # 20% for testing

# %% [markdown]
# # Training the Detection model

# %%
# Train and evaluate the model

from engine import train_one_epoch, evaluate
import utils

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has two classes only - background and person
num_classes = 2


# define training and validation data loaders
data_loader_training = torch.utils.data.DataLoader(
    dataset_training,
    batch_size=2,
    shuffle=True,
    num_workers=0,
    collate_fn=utils.collate_fn,
    generator=g
)

# define training and validation data loaders
data_loader_validation = torch.utils.data.DataLoader(
    dataset_validation,
    batch_size=1,
    shuffle=True,
    num_workers=0,
    collate_fn=utils.collate_fn,
    generator=g
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=1,
    shuffle=False,
    num_workers=0,
    collate_fn=utils.collate_fn,
    generator=g
)

# get the model using our helper function
model = get_detection_model(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)

# let's train it for 5 epochs
num_epochs = 5

metric_loggers = []

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    metric_logger = train_one_epoch(model, optimizer, data_loader_training, device, epoch, print_freq=10)
    metric_loggers.append(metric_logger)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset

for epoch in range(num_epochs):
    
    evaluate(model, data_loader_validation, device=device)

# TESTSET EVALUATION
#evaluate(model, data_loader_test, device=device)

PATH = "/Users/magnuswiik/Documents/NTNU/5.klasse/prosjektoppgave/FishID/models"

torch.save(model.state_dict(), PATH + "model_weights1_Masteroppgave.pt")

print("That's it!")
# Out:
# /Users/magnuswiik/miniconda3/envs/fisketrening/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch: [0]  [  0/551]  eta: 0:57:13  lr: 0.000014  loss: 1.0098 (1.0098)  loss_classifier: 0.7708 (0.7708)  loss_box_reg: 0.2051 (0.2051)  loss_objectness: 0.0231 (0.0231)  loss_rpn_box_reg: 0.0108 (0.0108)  time: 6.2321  data: 0.1410
# Epoch: [0]  [ 10/551]  eta: 0:50:43  lr: 0.000105  loss: 1.0990 (1.0992)  loss_classifier: 0.7081 (0.6749)  loss_box_reg: 0.3003 (0.2831)  loss_objectness: 0.0806 (0.1159)  loss_rpn_box_reg: 0.0227 (0.0253)  time: 5.6256  data: 0.1142
# Epoch: [0]  [ 20/551]  eta: 0:52:28  lr: 0.000196  loss: 0.9473 (0.9632)  loss_classifier: 0.4412 (0.5228)  loss_box_reg: 0.3093 (0.3191)  loss_objectness: 0.0676 (0.0961)  loss_rpn_box_reg: 0.0227 (0.0252)  time: 5.9150  data: 0.1144
# Epoch: [0]  [ 30/551]  eta: 0:50:46  lr: 0.000287  loss: 0.7045 (0.8687)  loss_classifier: 0.3021 (0.4465)  loss_box_reg: 0.3359 (0.3255)  loss_objectness: 0.0305 (0.0744)  loss_rpn_box_reg: 0.0181 (0.0222)  time: 5.9702  data: 0.1175
# Epoch: [0]  [ 40/551]  eta: 0:49:18  lr: 0.000377  loss: 0.5536 (0.7995)  loss_classifier: 0.2390 (0.3930)  loss_box_reg: 0.2913 (0.3180)  loss_objectness: 0.0304 (0.0663)  loss_rpn_box_reg: 0.0158 (0.0223)  time: 5.6424  data: 0.1137
# Epoch: [0]  [ 50/551]  eta: 0:47:25  lr: 0.000468  loss: 0.5914 (0.7692)  loss_classifier: 0.2330 (0.3645)  loss_box_reg: 0.3164 (0.3229)  loss_objectness: 0.0297 (0.0601)  loss_rpn_box_reg: 0.0157 (0.0217)  time: 5.4184  data: 0.1153
# Epoch: [0]  [ 60/551]  eta: 0:45:44  lr: 0.000559  loss: 0.5237 (0.7197)  loss_classifier: 0.2184 (0.3339)  loss_box_reg: 0.3047 (0.3092)  loss_objectness: 0.0269 (0.0555)  loss_rpn_box_reg: 0.0141 (0.0211)  time: 5.1771  data: 0.1109
# Epoch: [0]  [ 70/551]  eta: 0:44:10  lr: 0.000650  loss: 0.4430 (0.6819)  loss_classifier: 0.1680 (0.3105)  loss_box_reg: 0.2165 (0.3013)  loss_objectness: 0.0210 (0.0504)  loss_rpn_box_reg: 0.0102 (0.0198)  time: 5.0794  data: 0.1046
# Epoch: [0]  [ 80/551]  eta: 0:42:43  lr: 0.000741  loss: 0.4576 (0.7970)  loss_classifier: 0.1639 (0.2927)  loss_box_reg: 0.2374 (0.2943)  loss_objectness: 0.0265 (0.1118)  loss_rpn_box_reg: 0.0119 (0.0983)  time: 4.9972  data: 0.1047
# Epoch: [0]  [ 90/551]  eta: 0:41:36  lr: 0.000831  loss: 0.4859 (0.9252)  loss_classifier: 0.1584 (0.2776)  loss_box_reg: 0.2214 (0.2883)  loss_objectness: 0.0428 (0.1244)  loss_rpn_box_reg: 0.0150 (0.2348)  time: 5.0749  data: 0.1037
# Epoch: [0]  [100/551]  eta: 0:40:33  lr: 0.000922  loss: 0.4859 (0.8845)  loss_classifier: 0.1482 (0.2659)  loss_box_reg: 0.2529 (0.2889)  loss_objectness: 0.0351 (0.1168)  loss_rpn_box_reg: 0.0091 (0.2129)  time: 5.2104  data: 0.1095
# Epoch: [0]  [110/551]  eta: 0:39:50  lr: 0.001013  loss: 0.3731 (0.8347)  loss_classifier: 0.1135 (0.2516)  loss_box_reg: 0.2128 (0.2782)  loss_objectness: 0.0270 (0.1095)  loss_rpn_box_reg: 0.0099 (0.1953)  time: 5.4419  data: 0.1049
# Epoch: [0]  [120/551]  eta: 0:38:52  lr: 0.001104  loss: 0.3391 (0.7964)  loss_classifier: 0.1090 (0.2410)  loss_box_reg: 0.1774 (0.2731)  loss_objectness: 0.0175 (0.1021)  loss_rpn_box_reg: 0.0068 (0.1803)  time: 5.4935  data: 0.1016
# Epoch: [0]  [130/551]  eta: 0:37:56  lr: 0.001195  loss: 0.3676 (0.7651)  loss_classifier: 0.1193 (0.2322)  loss_box_reg: 0.2145 (0.2688)  loss_objectness: 0.0157 (0.0960)  loss_rpn_box_reg: 0.0083 (0.1682)  time: 5.3460  data: 0.1074
# Epoch: [0]  [140/551]  eta: 0:37:03  lr: 0.001286  loss: 0.3034 (0.7314)  loss_classifier: 0.1032 (0.2237)  loss_box_reg: 0.1725 (0.2605)  loss_objectness: 0.0157 (0.0901)  loss_rpn_box_reg: 0.0076 (0.1571)  time: 5.3921  data: 0.1059
# Epoch: [0]  [150/551]  eta: 0:36:02  lr: 0.001376  loss: 0.2473 (0.7008)  loss_classifier: 0.1017 (0.2159)  loss_box_reg: 0.1363 (0.2524)  loss_objectness: 0.0120 (0.0850)  loss_rpn_box_reg: 0.0063 (0.1475)  time: 5.2964  data: 0.1053
# Epoch: [0]  [160/551]  eta: 0:35:01  lr: 0.001467  loss: 0.2682 (0.6752)  loss_classifier: 0.1146 (0.2097)  loss_box_reg: 0.1258 (0.2459)  loss_objectness: 0.0109 (0.0806)  loss_rpn_box_reg: 0.0054 (0.1390)  time: 5.1344  data: 0.1122
# Epoch: [0]  [170/551]  eta: 0:33:59  lr: 0.001558  loss: 0.2179 (0.6490)  loss_classifier: 0.1042 (0.2031)  loss_box_reg: 0.1026 (0.2382)  loss_objectness: 0.0089 (0.0764)  loss_rpn_box_reg: 0.0048 (0.1313)  time: 5.0412  data: 0.1132
# Epoch: [0]  [180/551]  eta: 0:33:00  lr: 0.001649  loss: 0.2179 (0.6265)  loss_classifier: 0.0977 (0.1971)  loss_box_reg: 0.1001 (0.2323)  loss_objectness: 0.0077 (0.0727)  loss_rpn_box_reg: 0.0048 (0.1244)  time: 5.0460  data: 0.1055
# Epoch: [0]  [190/551]  eta: 0:32:08  lr: 0.001740  loss: 0.2726 (0.6093)  loss_classifier: 0.1073 (0.1934)  loss_box_reg: 0.1518 (0.2278)  loss_objectness: 0.0080 (0.0696)  loss_rpn_box_reg: 0.0055 (0.1184)  time: 5.2667  data: 0.1054
# Epoch: [0]  [200/551]  eta: 0:31:12  lr: 0.001830  loss: 0.2787 (0.5920)  loss_classifier: 0.1188 (0.1895)  loss_box_reg: 0.1387 (0.2228)  loss_objectness: 0.0082 (0.0667)  loss_rpn_box_reg: 0.0068 (0.1130)  time: 5.2859  data: 0.1086
# Epoch: [0]  [210/551]  eta: 0:30:16  lr: 0.001921  loss: 0.2316 (0.5751)  loss_classifier: 0.1049 (0.1850)  loss_box_reg: 0.1044 (0.2176)  loss_objectness: 0.0110 (0.0642)  loss_rpn_box_reg: 0.0076 (0.1083)  time: 5.1802  data: 0.1006
# Epoch: [0]  [220/551]  eta: 0:29:21  lr: 0.002012  loss: 0.2363 (0.5613)  loss_classifier: 0.0953 (0.1819)  loss_box_reg: 0.1191 (0.2142)  loss_objectness: 0.0067 (0.0616)  loss_rpn_box_reg: 0.0059 (0.1036)  time: 5.1944  data: 0.1062
# Epoch: [0]  [230/551]  eta: 0:28:27  lr: 0.002103  loss: 0.2363 (0.5469)  loss_classifier: 0.1031 (0.1782)  loss_box_reg: 0.1179 (0.2097)  loss_objectness: 0.0058 (0.0594)  loss_rpn_box_reg: 0.0044 (0.0996)  time: 5.2179  data: 0.1162
# Epoch: [0]  [240/551]  eta: 0:27:33  lr: 0.002194  loss: 0.2331 (0.5351)  loss_classifier: 0.1031 (0.1754)  loss_box_reg: 0.1179 (0.2067)  loss_objectness: 0.0058 (0.0573)  loss_rpn_box_reg: 0.0051 (0.0958)  time: 5.2617  data: 0.1134
# Epoch: [0]  [250/551]  eta: 0:26:39  lr: 0.002285  loss: 0.2459 (0.5249)  loss_classifier: 0.1057 (0.1730)  loss_box_reg: 0.1295 (0.2040)  loss_objectness: 0.0086 (0.0555)  loss_rpn_box_reg: 0.0072 (0.0924)  time: 5.2536  data: 0.1133
# Epoch: [0]  [260/551]  eta: 0:25:46  lr: 0.002375  loss: 0.2473 (0.5138)  loss_classifier: 0.1041 (0.1699)  loss_box_reg: 0.1295 (0.2010)  loss_objectness: 0.0089 (0.0537)  loss_rpn_box_reg: 0.0050 (0.0892)  time: 5.2824  data: 0.1098
# Epoch: [0]  [270/551]  eta: 0:24:51  lr: 0.002466  loss: 0.2085 (0.5033)  loss_classifier: 0.0945 (0.1668)  loss_box_reg: 0.1105 (0.1981)  loss_objectness: 0.0057 (0.0520)  loss_rpn_box_reg: 0.0048 (0.0863)  time: 5.2499  data: 0.1101
# Epoch: [0]  [280/551]  eta: 0:23:59  lr: 0.002557  loss: 0.1944 (0.4924)  loss_classifier: 0.0833 (0.1641)  loss_box_reg: 0.1008 (0.1943)  loss_objectness: 0.0047 (0.0504)  loss_rpn_box_reg: 0.0058 (0.0836)  time: 5.2950  data: 0.1085
# Epoch: [0]  [290/551]  eta: 0:23:03  lr: 0.002648  loss: 0.1698 (0.4808)  loss_classifier: 0.0647 (0.1604)  loss_box_reg: 0.0805 (0.1904)  loss_objectness: 0.0039 (0.0489)  loss_rpn_box_reg: 0.0055 (0.0810)  time: 5.1957  data: 0.1029
# Epoch: [0]  [300/551]  eta: 0:22:06  lr: 0.002739  loss: 0.1698 (0.4722)  loss_classifier: 0.0628 (0.1584)  loss_box_reg: 0.0960 (0.1876)  loss_objectness: 0.0068 (0.0477)  loss_rpn_box_reg: 0.0061 (0.0786)  time: 4.8982  data: 0.1025
# Epoch: [0]  [310/551]  eta: 0:21:13  lr: 0.002829  loss: 0.2310 (0.4651)  loss_classifier: 0.1006 (0.1564)  loss_box_reg: 0.1104 (0.1859)  loss_objectness: 0.0085 (0.0464)  loss_rpn_box_reg: 0.0059 (0.0764)  time: 5.0743  data: 0.1075
# Epoch: [0]  [320/551]  eta: 0:20:21  lr: 0.002920  loss: 0.2286 (0.4581)  loss_classifier: 0.0975 (0.1547)  loss_box_reg: 0.1167 (0.1839)  loss_objectness: 0.0085 (0.0453)  loss_rpn_box_reg: 0.0054 (0.0743)  time: 5.3219  data: 0.1095
# Epoch: [0]  [330/551]  eta: 0:19:27  lr: 0.003011  loss: 0.2286 (0.4518)  loss_classifier: 0.0960 (0.1531)  loss_box_reg: 0.1263 (0.1821)  loss_objectness: 0.0051 (0.0443)  loss_rpn_box_reg: 0.0052 (0.0723)  time: 5.2416  data: 0.1074
# Epoch: [0]  [340/551]  eta: 0:18:33  lr: 0.003102  loss: 0.2598 (0.4468)  loss_classifier: 0.1012 (0.1519)  loss_box_reg: 0.1481 (0.1812)  loss_objectness: 0.0070 (0.0433)  loss_rpn_box_reg: 0.0062 (0.0704)  time: 5.1355  data: 0.1148
# Epoch: [0]  [350/551]  eta: 0:17:39  lr: 0.003193  loss: 0.2518 (0.4401)  loss_classifier: 0.0929 (0.1498)  loss_box_reg: 0.1188 (0.1793)  loss_objectness: 0.0075 (0.0424)  loss_rpn_box_reg: 0.0058 (0.0686)  time: 5.0898  data: 0.1137
# Epoch: [0]  [360/551]  eta: 0:16:47  lr: 0.003284  loss: 0.2021 (0.4339)  loss_classifier: 0.0782 (0.1481)  loss_box_reg: 0.1065 (0.1774)  loss_objectness: 0.0058 (0.0414)  loss_rpn_box_reg: 0.0057 (0.0670)  time: 5.2391  data: 0.1033
# Epoch: [0]  [370/551]  eta: 0:15:54  lr: 0.003374  loss: 0.1841 (0.4270)  loss_classifier: 0.0805 (0.1462)  loss_box_reg: 0.0749 (0.1749)  loss_objectness: 0.0058 (0.0404)  loss_rpn_box_reg: 0.0057 (0.0655)  time: 5.2753  data: 0.1006
# Epoch: [0]  [380/551]  eta: 0:15:01  lr: 0.003465  loss: 0.1728 (0.4210)  loss_classifier: 0.0807 (0.1446)  loss_box_reg: 0.0787 (0.1729)  loss_objectness: 0.0066 (0.0396)  loss_rpn_box_reg: 0.0052 (0.0639)  time: 5.2254  data: 0.1083
# Epoch: [0]  [390/551]  eta: 0:14:07  lr: 0.003556  loss: 0.2059 (0.4167)  loss_classifier: 0.0829 (0.1434)  loss_box_reg: 0.1026 (0.1720)  loss_objectness: 0.0077 (0.0388)  loss_rpn_box_reg: 0.0057 (0.0625)  time: 5.1494  data: 0.1134
# Epoch: [0]  [400/551]  eta: 0:13:14  lr: 0.003647  loss: 0.2066 (0.4117)  loss_classifier: 0.0789 (0.1417)  loss_box_reg: 0.1057 (0.1708)  loss_objectness: 0.0063 (0.0380)  loss_rpn_box_reg: 0.0064 (0.0612)  time: 4.9927  data: 0.1105
# Epoch: [0]  [410/551]  eta: 0:12:21  lr: 0.003738  loss: 0.1859 (0.4056)  loss_classifier: 0.0689 (0.1400)  loss_box_reg: 0.0965 (0.1686)  loss_objectness: 0.0033 (0.0372)  loss_rpn_box_reg: 0.0049 (0.0598)  time: 5.1077  data: 0.1052
# Epoch: [0]  [420/551]  eta: 0:11:28  lr: 0.003828  loss: 0.2186 (0.4030)  loss_classifier: 0.0780 (0.1392)  loss_box_reg: 0.1314 (0.1687)  loss_objectness: 0.0040 (0.0366)  loss_rpn_box_reg: 0.0049 (0.0586)  time: 5.1908  data: 0.1098
# Epoch: [0]  [430/551]  eta: 0:10:35  lr: 0.003919  loss: 0.2316 (0.3980)  loss_classifier: 0.0810 (0.1375)  loss_box_reg: 0.1222 (0.1671)  loss_objectness: 0.0041 (0.0359)  loss_rpn_box_reg: 0.0052 (0.0575)  time: 5.0925  data: 0.1104
# Epoch: [0]  [440/551]  eta: 0:09:42  lr: 0.004010  loss: 0.1662 (0.3927)  loss_classifier: 0.0733 (0.1360)  loss_box_reg: 0.0913 (0.1652)  loss_objectness: 0.0041 (0.0352)  loss_rpn_box_reg: 0.0034 (0.0563)  time: 5.1233  data: 0.1073
# Epoch: [0]  [450/551]  eta: 0:08:50  lr: 0.004101  loss: 0.1833 (0.3884)  loss_classifier: 0.0713 (0.1346)  loss_box_reg: 0.0887 (0.1640)  loss_objectness: 0.0048 (0.0345)  loss_rpn_box_reg: 0.0036 (0.0553)  time: 5.2053  data: 0.1110
# Epoch: [0]  [460/551]  eta: 0:07:57  lr: 0.004192  loss: 0.1922 (0.3839)  loss_classifier: 0.0654 (0.1334)  loss_box_reg: 0.0982 (0.1625)  loss_objectness: 0.0030 (0.0339)  loss_rpn_box_reg: 0.0036 (0.0542)  time: 5.1372  data: 0.1107
# Epoch: [0]  [470/551]  eta: 0:07:04  lr: 0.004283  loss: 0.1832 (0.3804)  loss_classifier: 0.0747 (0.1323)  loss_box_reg: 0.0982 (0.1616)  loss_objectness: 0.0030 (0.0334)  loss_rpn_box_reg: 0.0038 (0.0532)  time: 5.1504  data: 0.1158
# Epoch: [0]  [480/551]  eta: 0:06:12  lr: 0.004373  loss: 0.1832 (0.3769)  loss_classifier: 0.0771 (0.1313)  loss_box_reg: 0.1197 (0.1604)  loss_objectness: 0.0048 (0.0329)  loss_rpn_box_reg: 0.0057 (0.0523)  time: 5.1649  data: 0.1127
# Epoch: [0]  [490/551]  eta: 0:05:19  lr: 0.004464  loss: 0.1922 (0.3733)  loss_classifier: 0.0753 (0.1302)  loss_box_reg: 0.0888 (0.1593)  loss_objectness: 0.0054 (0.0323)  loss_rpn_box_reg: 0.0057 (0.0515)  time: 5.0319  data: 0.1011
# Epoch: [0]  [500/551]  eta: 0:04:26  lr: 0.004555  loss: 0.2058 (0.3699)  loss_classifier: 0.0732 (0.1293)  loss_box_reg: 0.0918 (0.1581)  loss_objectness: 0.0055 (0.0319)  loss_rpn_box_reg: 0.0057 (0.0507)  time: 4.9483  data: 0.0978
# Epoch: [0]  [510/551]  eta: 0:03:34  lr: 0.004646  loss: 0.1811 (0.3661)  loss_classifier: 0.0781 (0.1282)  loss_box_reg: 0.0853 (0.1566)  loss_objectness: 0.0055 (0.0314)  loss_rpn_box_reg: 0.0060 (0.0499)  time: 4.9713  data: 0.0974
# Epoch: [0]  [520/551]  eta: 0:02:42  lr: 0.004737  loss: 0.1811 (0.3633)  loss_classifier: 0.0784 (0.1275)  loss_box_reg: 0.0864 (0.1557)  loss_objectness: 0.0049 (0.0309)  loss_rpn_box_reg: 0.0064 (0.0491)  time: 5.1194  data: 0.1017
# Epoch: [0]  [530/551]  eta: 0:01:49  lr: 0.004827  loss: 0.2242 (0.3606)  loss_classifier: 0.0782 (0.1267)  loss_box_reg: 0.1168 (0.1550)  loss_objectness: 0.0064 (0.0305)  loss_rpn_box_reg: 0.0068 (0.0485)  time: 5.2055  data: 0.1066
# Epoch: [0]  [540/551]  eta: 0:00:57  lr: 0.004918  loss: 0.2060 (0.3577)  loss_classifier: 0.0782 (0.1257)  loss_box_reg: 0.1051 (0.1537)  loss_objectness: 0.0076 (0.0303)  loss_rpn_box_reg: 0.0068 (0.0479)  time: 5.0988  data: 0.1020
# Epoch: [0]  [550/551]  eta: 0:00:05  lr: 0.005000  loss: 0.2039 (0.3553)  loss_classifier: 0.0717 (0.1250)  loss_box_reg: 0.1051 (0.1532)  loss_objectness: 0.0068 (0.0299)  loss_rpn_box_reg: 0.0063 (0.0472)  time: 5.0369  data: 0.1038
# Epoch: [0] Total time: 0:47:55 (5.2182 s / it)
# Epoch: [1]  [  0/551]  eta: 0:48:42  lr: 0.005000  loss: 0.1819 (0.1819)  loss_classifier: 0.0506 (0.0506)  loss_box_reg: 0.1138 (0.1138)  loss_objectness: 0.0108 (0.0108)  loss_rpn_box_reg: 0.0066 (0.0066)  time: 5.3038  data: 0.0876
# Epoch: [1]  [ 10/551]  eta: 0:46:48  lr: 0.005000  loss: 0.1926 (0.1890)  loss_classifier: 0.0674 (0.0641)  loss_box_reg: 0.1117 (0.1103)  loss_objectness: 0.0036 (0.0069)  loss_rpn_box_reg: 0.0071 (0.0076)  time: 5.1922  data: 0.1029
# Epoch: [1]  [ 20/551]  eta: 0:45:18  lr: 0.005000  loss: 0.1776 (0.1860)  loss_classifier: 0.0674 (0.0675)  loss_box_reg: 0.0890 (0.1009)  loss_objectness: 0.0045 (0.0073)  loss_rpn_box_reg: 0.0073 (0.0102)  time: 5.1106  data: 0.1032
# Epoch: [1]  [ 30/551]  eta: 0:43:52  lr: 0.005000  loss: 0.1753 (0.1887)  loss_classifier: 0.0674 (0.0692)  loss_box_reg: 0.0873 (0.1015)  loss_objectness: 0.0045 (0.0077)  loss_rpn_box_reg: 0.0072 (0.0102)  time: 4.9775  data: 0.1045
# Epoch: [1]  [ 40/551]  eta: 0:42:37  lr: 0.005000  loss: 0.1753 (0.1864)  loss_classifier: 0.0668 (0.0703)  loss_box_reg: 0.0905 (0.0989)  loss_objectness: 0.0038 (0.0074)  loss_rpn_box_reg: 0.0050 (0.0098)  time: 4.8845  data: 0.1037
# Epoch: [1]  [ 50/551]  eta: 0:41:57  lr: 0.005000  loss: 0.2043 (0.1927)  loss_classifier: 0.0753 (0.0733)  loss_box_reg: 0.0984 (0.1025)  loss_objectness: 0.0047 (0.0070)  loss_rpn_box_reg: 0.0063 (0.0099)  time: 4.9780  data: 0.1060
# Epoch: [1]  [ 60/551]  eta: 0:41:20  lr: 0.005000  loss: 0.2165 (0.1911)  loss_classifier: 0.0703 (0.0727)  loss_box_reg: 0.0997 (0.1019)  loss_objectness: 0.0040 (0.0069)  loss_rpn_box_reg: 0.0064 (0.0097)  time: 5.1454  data: 0.1116
# Epoch: [1]  [ 70/551]  eta: 0:40:38  lr: 0.005000  loss: 0.1661 (0.1924)  loss_classifier: 0.0662 (0.0746)  loss_box_reg: 0.0988 (0.1010)  loss_objectness: 0.0048 (0.0075)  loss_rpn_box_reg: 0.0056 (0.0094)  time: 5.1866  data: 0.1110
# Epoch: [1]  [ 80/551]  eta: 0:39:54  lr: 0.005000  loss: 0.2002 (0.1969)  loss_classifier: 0.0818 (0.0755)  loss_box_reg: 0.1124 (0.1054)  loss_objectness: 0.0051 (0.0071)  loss_rpn_box_reg: 0.0044 (0.0089)  time: 5.1833  data: 0.1161
# Epoch: [1]  [ 90/551]  eta: 0:39:08  lr: 0.005000  loss: 0.2002 (0.1977)  loss_classifier: 0.0831 (0.0762)  loss_box_reg: 0.1139 (0.1061)  loss_objectness: 0.0034 (0.0069)  loss_rpn_box_reg: 0.0042 (0.0085)  time: 5.1792  data: 0.1156
# Epoch: [1]  [100/551]  eta: 0:38:13  lr: 0.005000  loss: 0.1532 (0.1926)  loss_classifier: 0.0599 (0.0739)  loss_box_reg: 0.0839 (0.1037)  loss_objectness: 0.0035 (0.0066)  loss_rpn_box_reg: 0.0047 (0.0083)  time: 5.0880  data: 0.1061
# Epoch: [1]  [110/551]  eta: 0:37:20  lr: 0.005000  loss: 0.1404 (0.1911)  loss_classifier: 0.0580 (0.0742)  loss_box_reg: 0.0801 (0.1023)  loss_objectness: 0.0036 (0.0065)  loss_rpn_box_reg: 0.0048 (0.0082)  time: 5.0199  data: 0.1020
# Epoch: [1]  [120/551]  eta: 0:36:32  lr: 0.005000  loss: 0.1739 (0.1913)  loss_classifier: 0.0669 (0.0746)  loss_box_reg: 0.0905 (0.1018)  loss_objectness: 0.0040 (0.0065)  loss_rpn_box_reg: 0.0056 (0.0084)  time: 5.0941  data: 0.1038
# Epoch: [1]  [130/551]  eta: 0:35:44  lr: 0.005000  loss: 0.2077 (0.1933)  loss_classifier: 0.0716 (0.0752)  loss_box_reg: 0.1082 (0.1030)  loss_objectness: 0.0035 (0.0065)  loss_rpn_box_reg: 0.0056 (0.0086)  time: 5.1736  data: 0.1096
# Epoch: [1]  [140/551]  eta: 0:34:55  lr: 0.005000  loss: 0.1920 (0.1928)  loss_classifier: 0.0652 (0.0749)  loss_box_reg: 0.1083 (0.1030)  loss_objectness: 0.0024 (0.0064)  loss_rpn_box_reg: 0.0051 (0.0085)  time: 5.1812  data: 0.1131
# Epoch: [1]  [150/551]  eta: 0:34:08  lr: 0.005000  loss: 0.1716 (0.1914)  loss_classifier: 0.0684 (0.0748)  loss_box_reg: 0.0934 (0.1019)  loss_objectness: 0.0033 (0.0063)  loss_rpn_box_reg: 0.0043 (0.0085)  time: 5.1975  data: 0.1104
# Epoch: [1]  [160/551]  eta: 0:33:16  lr: 0.005000  loss: 0.1410 (0.1881)  loss_classifier: 0.0556 (0.0733)  loss_box_reg: 0.0795 (0.1005)  loss_objectness: 0.0027 (0.0061)  loss_rpn_box_reg: 0.0041 (0.0082)  time: 5.1427  data: 0.1099
# Epoch: [1]  [170/551]  eta: 0:32:29  lr: 0.005000  loss: 0.1338 (0.1854)  loss_classifier: 0.0416 (0.0716)  loss_box_reg: 0.0796 (0.0998)  loss_objectness: 0.0023 (0.0060)  loss_rpn_box_reg: 0.0033 (0.0080)  time: 5.1879  data: 0.1053
# Epoch: [1]  [180/551]  eta: 0:31:40  lr: 0.005000  loss: 0.1720 (0.1854)  loss_classifier: 0.0561 (0.0711)  loss_box_reg: 0.0911 (0.1003)  loss_objectness: 0.0023 (0.0060)  loss_rpn_box_reg: 0.0036 (0.0080)  time: 5.2677  data: 0.1041
# Epoch: [1]  [190/551]  eta: 0:30:49  lr: 0.005000  loss: 0.1870 (0.1845)  loss_classifier: 0.0632 (0.0703)  loss_box_reg: 0.1163 (0.1005)  loss_objectness: 0.0011 (0.0058)  loss_rpn_box_reg: 0.0036 (0.0079)  time: 5.1843  data: 0.1121
# Epoch: [1]  [200/551]  eta: 0:30:00  lr: 0.005000  loss: 0.1711 (0.1828)  loss_classifier: 0.0614 (0.0693)  loss_box_reg: 0.0946 (0.1001)  loss_objectness: 0.0011 (0.0056)  loss_rpn_box_reg: 0.0026 (0.0078)  time: 5.1992  data: 0.1065
# Epoch: [1]  [210/551]  eta: 0:29:09  lr: 0.005000  loss: 0.1899 (0.1838)  loss_classifier: 0.0661 (0.0701)  loss_box_reg: 0.0835 (0.1004)  loss_objectness: 0.0025 (0.0056)  loss_rpn_box_reg: 0.0032 (0.0077)  time: 5.1934  data: 0.1067
# Epoch: [1]  [220/551]  eta: 0:28:18  lr: 0.005000  loss: 0.1823 (0.1826)  loss_classifier: 0.0742 (0.0700)  loss_box_reg: 0.0767 (0.0997)  loss_objectness: 0.0014 (0.0054)  loss_rpn_box_reg: 0.0029 (0.0075)  time: 5.1288  data: 0.1126
# Epoch: [1]  [230/551]  eta: 0:27:27  lr: 0.005000  loss: 0.1479 (0.1810)  loss_classifier: 0.0513 (0.0692)  loss_box_reg: 0.0806 (0.0991)  loss_objectness: 0.0011 (0.0053)  loss_rpn_box_reg: 0.0028 (0.0074)  time: 5.1315  data: 0.1101
# Epoch: [1]  [240/551]  eta: 0:26:35  lr: 0.005000  loss: 0.1687 (0.1816)  loss_classifier: 0.0528 (0.0693)  loss_box_reg: 0.1052 (0.0997)  loss_objectness: 0.0022 (0.0053)  loss_rpn_box_reg: 0.0040 (0.0073)  time: 5.1197  data: 0.1116
# Epoch: [1]  [250/551]  eta: 0:25:42  lr: 0.005000  loss: 0.2015 (0.1815)  loss_classifier: 0.0781 (0.0693)  loss_box_reg: 0.1065 (0.0997)  loss_objectness: 0.0019 (0.0052)  loss_rpn_box_reg: 0.0047 (0.0073)  time: 5.0593  data: 0.1149
# Epoch: [1]  [260/551]  eta: 0:24:50  lr: 0.005000  loss: 0.1812 (0.1813)  loss_classifier: 0.0674 (0.0692)  loss_box_reg: 0.1009 (0.0994)  loss_objectness: 0.0019 (0.0053)  loss_rpn_box_reg: 0.0063 (0.0074)  time: 5.0382  data: 0.1124
# Epoch: [1]  [270/551]  eta: 0:23:57  lr: 0.005000  loss: 0.2089 (0.2400)  loss_classifier: 0.0620 (0.0688)  loss_box_reg: 0.0821 (0.0987)  loss_objectness: 0.0087 (0.0221)  loss_rpn_box_reg: 0.0076 (0.0504)  time: 4.9794  data: 0.1031
# Epoch: [1]  [280/551]  eta: 0:23:04  lr: 0.005000  loss: 0.2114 (0.2395)  loss_classifier: 0.0574 (0.0690)  loss_box_reg: 0.0828 (0.0985)  loss_objectness: 0.0299 (0.0227)  loss_rpn_box_reg: 0.0078 (0.0493)  time: 4.9337  data: 0.1031
# Epoch: [1]  [290/551]  eta: 0:22:13  lr: 0.005000  loss: 0.1733 (0.2370)  loss_classifier: 0.0574 (0.0687)  loss_box_reg: 0.0954 (0.0980)  loss_objectness: 0.0150 (0.0224)  loss_rpn_box_reg: 0.0070 (0.0479)  time: 5.0379  data: 0.1071
# Epoch: [1]  [300/551]  eta: 0:21:24  lr: 0.005000  loss: 0.1390 (0.2337)  loss_classifier: 0.0520 (0.0681)  loss_box_reg: 0.0687 (0.0971)  loss_objectness: 0.0090 (0.0219)  loss_rpn_box_reg: 0.0047 (0.0466)  time: 5.2163  data: 0.1041
# Epoch: [1]  [310/551]  eta: 0:20:32  lr: 0.005000  loss: 0.1427 (0.2316)  loss_classifier: 0.0542 (0.0682)  loss_box_reg: 0.0584 (0.0966)  loss_objectness: 0.0066 (0.0214)  loss_rpn_box_reg: 0.0046 (0.0455)  time: 5.1777  data: 0.1076
# Epoch: [1]  [320/551]  eta: 0:19:39  lr: 0.005000  loss: 0.1786 (0.2634)  loss_classifier: 0.0654 (0.0679)  loss_box_reg: 0.0824 (0.0968)  loss_objectness: 0.0066 (0.0274)  loss_rpn_box_reg: 0.0057 (0.0713)  time: 4.9633  data: 0.1065
# Epoch: [1]  [330/551]  eta: 0:18:48  lr: 0.005000  loss: 0.1797 (0.2604)  loss_classifier: 0.0551 (0.0674)  loss_box_reg: 0.0848 (0.0963)  loss_objectness: 0.0113 (0.0273)  loss_rpn_box_reg: 0.0068 (0.0693)  time: 4.9976  data: 0.1033
# Epoch: [1]  [340/551]  eta: 0:17:57  lr: 0.005000  loss: 0.1639 (0.2573)  loss_classifier: 0.0519 (0.0671)  loss_box_reg: 0.0786 (0.0959)  loss_objectness: 0.0125 (0.0269)  loss_rpn_box_reg: 0.0047 (0.0675)  time: 5.0919  data: 0.1100
# Epoch: [1]  [350/551]  eta: 0:17:06  lr: 0.005000  loss: 0.1664 (0.2550)  loss_classifier: 0.0578 (0.0670)  loss_box_reg: 0.0834 (0.0959)  loss_objectness: 0.0066 (0.0263)  loss_rpn_box_reg: 0.0044 (0.0658)  time: 5.1519  data: 0.1090
# Epoch: [1]  [360/551]  eta: 0:16:17  lr: 0.005000  loss: 0.1683 (0.2524)  loss_classifier: 0.0600 (0.0668)  loss_box_reg: 0.0834 (0.0956)  loss_objectness: 0.0070 (0.0259)  loss_rpn_box_reg: 0.0040 (0.0642)  time: 5.3332  data: 0.1067
# Epoch: [1]  [370/551]  eta: 0:15:25  lr: 0.005000  loss: 0.1507 (0.2500)  loss_classifier: 0.0555 (0.0665)  loss_box_reg: 0.0913 (0.0957)  loss_objectness: 0.0035 (0.0252)  loss_rpn_box_reg: 0.0031 (0.0626)  time: 5.1982  data: 0.1110
# Epoch: [1]  [380/551]  eta: 0:14:34  lr: 0.005000  loss: 0.1442 (0.2472)  loss_classifier: 0.0543 (0.0662)  loss_box_reg: 0.0909 (0.0952)  loss_objectness: 0.0031 (0.0247)  loss_rpn_box_reg: 0.0036 (0.0611)  time: 4.9882  data: 0.1135
# Epoch: [1]  [390/551]  eta: 0:13:41  lr: 0.005000  loss: 0.1250 (0.2447)  loss_classifier: 0.0488 (0.0659)  loss_box_reg: 0.0630 (0.0949)  loss_objectness: 0.0039 (0.0242)  loss_rpn_box_reg: 0.0043 (0.0596)  time: 4.8716  data: 0.1112
# Epoch: [1]  [400/551]  eta: 0:12:49  lr: 0.005000  loss: 0.1564 (0.2426)  loss_classifier: 0.0557 (0.0659)  loss_box_reg: 0.0856 (0.0946)  loss_objectness: 0.0029 (0.0238)  loss_rpn_box_reg: 0.0037 (0.0584)  time: 4.7743  data: 0.1080
# Epoch: [1]  [410/551]  eta: 0:11:57  lr: 0.005000  loss: 0.1470 (0.2399)  loss_classifier: 0.0583 (0.0656)  loss_box_reg: 0.0801 (0.0940)  loss_objectness: 0.0025 (0.0232)  loss_rpn_box_reg: 0.0035 (0.0571)  time: 4.8385  data: 0.1129
# Epoch: [1]  [420/551]  eta: 0:11:06  lr: 0.005000  loss: 0.1327 (0.2375)  loss_classifier: 0.0511 (0.0654)  loss_box_reg: 0.0623 (0.0934)  loss_objectness: 0.0027 (0.0228)  loss_rpn_box_reg: 0.0035 (0.0559)  time: 4.9023  data: 0.1099
# Epoch: [1]  [430/551]  eta: 0:10:14  lr: 0.005000  loss: 0.1584 (0.2359)  loss_classifier: 0.0564 (0.0655)  loss_box_reg: 0.0844 (0.0932)  loss_objectness: 0.0035 (0.0224)  loss_rpn_box_reg: 0.0041 (0.0547)  time: 4.9190  data: 0.1065
# Epoch: [1]  [440/551]  eta: 0:09:23  lr: 0.005000  loss: 0.1660 (0.2339)  loss_classifier: 0.0637 (0.0652)  loss_box_reg: 0.0844 (0.0928)  loss_objectness: 0.0027 (0.0221)  loss_rpn_box_reg: 0.0055 (0.0537)  time: 4.8237  data: 0.1049
# Epoch: [1]  [450/551]  eta: 0:08:31  lr: 0.005000  loss: 0.1360 (0.2319)  loss_classifier: 0.0470 (0.0651)  loss_box_reg: 0.0758 (0.0924)  loss_objectness: 0.0032 (0.0217)  loss_rpn_box_reg: 0.0051 (0.0527)  time: 4.7883  data: 0.1040
# Epoch: [1]  [460/551]  eta: 0:07:40  lr: 0.005000  loss: 0.1360 (0.2534)  loss_classifier: 0.0471 (0.0646)  loss_box_reg: 0.0629 (0.0924)  loss_objectness: 0.0057 (0.0261)  loss_rpn_box_reg: 0.0055 (0.0702)  time: 4.8181  data: 0.1032
# Epoch: [1]  [470/551]  eta: 0:06:49  lr: 0.005000  loss: 0.1618 (0.2516)  loss_classifier: 0.0482 (0.0646)  loss_box_reg: 0.0690 (0.0922)  loss_objectness: 0.0110 (0.0259)  loss_rpn_box_reg: 0.0056 (0.0689)  time: 4.8425  data: 0.1057
# Epoch: [1]  [480/551]  eta: 0:05:58  lr: 0.005000  loss: 0.1405 (0.2495)  loss_classifier: 0.0503 (0.0644)  loss_box_reg: 0.0773 (0.0920)  loss_objectness: 0.0067 (0.0255)  loss_rpn_box_reg: 0.0043 (0.0676)  time: 4.8839  data: 0.1167
# Epoch: [1]  [490/551]  eta: 0:05:08  lr: 0.005000  loss: 0.1451 (0.2477)  loss_classifier: 0.0567 (0.0645)  loss_box_reg: 0.0765 (0.0916)  loss_objectness: 0.0038 (0.0252)  loss_rpn_box_reg: 0.0036 (0.0664)  time: 4.8924  data: 0.1142
# Epoch: [1]  [500/551]  eta: 0:04:18  lr: 0.005000  loss: 0.1451 (0.2456)  loss_classifier: 0.0601 (0.0644)  loss_box_reg: 0.0727 (0.0912)  loss_objectness: 0.0025 (0.0249)  loss_rpn_box_reg: 0.0036 (0.0652)  time: 5.1881  data: 0.1088
# Epoch: [1]  [510/551]  eta: 0:03:27  lr: 0.005000  loss: 0.1669 (0.2445)  loss_classifier: 0.0623 (0.0646)  loss_box_reg: 0.0840 (0.0914)  loss_objectness: 0.0038 (0.0245)  loss_rpn_box_reg: 0.0041 (0.0641)  time: 5.3481  data: 0.1108
# Epoch: [1]  [520/551]  eta: 0:02:37  lr: 0.005000  loss: 0.1933 (0.2431)  loss_classifier: 0.0639 (0.0646)  loss_box_reg: 0.0936 (0.0914)  loss_objectness: 0.0043 (0.0242)  loss_rpn_box_reg: 0.0059 (0.0630)  time: 5.3048  data: 0.1154
# Epoch: [1]  [530/551]  eta: 0:01:46  lr: 0.005000  loss: 0.1350 (0.2415)  loss_classifier: 0.0567 (0.0644)  loss_box_reg: 0.0755 (0.0913)  loss_objectness: 0.0041 (0.0238)  loss_rpn_box_reg: 0.0055 (0.0619)  time: 5.2842  data: 0.1128
# Epoch: [1]  [540/551]  eta: 0:00:55  lr: 0.005000  loss: 0.1485 (0.2400)  loss_classifier: 0.0577 (0.0644)  loss_box_reg: 0.0749 (0.0912)  loss_objectness: 0.0018 (0.0235)  loss_rpn_box_reg: 0.0029 (0.0610)  time: 5.2951  data: 0.1024
# Epoch: [1]  [550/551]  eta: 0:00:05  lr: 0.005000  loss: 0.1572 (0.2385)  loss_classifier: 0.0577 (0.0644)  loss_box_reg: 0.0796 (0.0909)  loss_objectness: 0.0064 (0.0232)  loss_rpn_box_reg: 0.0038 (0.0600)  time: 5.3184  data: 0.0958
# Epoch: [1] Total time: 0:46:39 (5.0807 s / it)
# Epoch: [2]  [  0/551]  eta: 0:47:17  lr: 0.005000  loss: 0.1546 (0.1546)  loss_classifier: 0.0549 (0.0549)  loss_box_reg: 0.0745 (0.0745)  loss_objectness: 0.0172 (0.0172)  loss_rpn_box_reg: 0.0079 (0.0079)  time: 5.1503  data: 0.1297
# Epoch: [2]  [ 10/551]  eta: 0:42:16  lr: 0.005000  loss: 0.1029 (0.1191)  loss_classifier: 0.0436 (0.0460)  loss_box_reg: 0.0609 (0.0593)  loss_objectness: 0.0041 (0.0057)  loss_rpn_box_reg: 0.0065 (0.0081)  time: 4.6881  data: 0.0976
# Epoch: [2]  [ 20/551]  eta: 0:42:06  lr: 0.005000  loss: 0.1517 (0.1380)  loss_classifier: 0.0487 (0.0533)  loss_box_reg: 0.0825 (0.0745)  loss_objectness: 0.0015 (0.0036)  loss_rpn_box_reg: 0.0057 (0.0066)  time: 4.7375  data: 0.1064
# Epoch: [2]  [ 30/551]  eta: 0:41:38  lr: 0.005000  loss: 0.1536 (0.1396)  loss_classifier: 0.0544 (0.0524)  loss_box_reg: 0.0952 (0.0772)  loss_objectness: 0.0015 (0.0036)  loss_rpn_box_reg: 0.0048 (0.0064)  time: 4.8533  data: 0.1138
# Epoch: [2]  [ 40/551]  eta: 0:40:49  lr: 0.005000  loss: 0.1508 (0.1482)  loss_classifier: 0.0550 (0.0548)  loss_box_reg: 0.0750 (0.0823)  loss_objectness: 0.0024 (0.0042)  loss_rpn_box_reg: 0.0045 (0.0069)  time: 4.8312  data: 0.1053
# Epoch: [2]  [ 50/551]  eta: 0:40:10  lr: 0.005000  loss: 0.1498 (0.1481)  loss_classifier: 0.0471 (0.0543)  loss_box_reg: 0.0870 (0.0821)  loss_objectness: 0.0038 (0.0046)  loss_rpn_box_reg: 0.0045 (0.0071)  time: 4.8384  data: 0.0983
# Epoch: [2]  [ 60/551]  eta: 0:39:23  lr: 0.005000  loss: 0.1449 (0.1485)  loss_classifier: 0.0459 (0.0541)  loss_box_reg: 0.0719 (0.0821)  loss_objectness: 0.0039 (0.0049)  loss_rpn_box_reg: 0.0041 (0.0075)  time: 4.8569  data: 0.0955
# Epoch: [2]  [ 70/551]  eta: 0:38:32  lr: 0.005000  loss: 0.1427 (0.1507)  loss_classifier: 0.0459 (0.0546)  loss_box_reg: 0.0753 (0.0840)  loss_objectness: 0.0028 (0.0047)  loss_rpn_box_reg: 0.0031 (0.0073)  time: 4.7989  data: 0.1035
# Epoch: [2]  [ 80/551]  eta: 0:37:50  lr: 0.005000  loss: 0.1427 (0.1493)  loss_classifier: 0.0549 (0.0545)  loss_box_reg: 0.0869 (0.0834)  loss_objectness: 0.0020 (0.0045)  loss_rpn_box_reg: 0.0034 (0.0069)  time: 4.8362  data: 0.1134
# Epoch: [2]  [ 90/551]  eta: 0:37:10  lr: 0.005000  loss: 0.1564 (0.1523)  loss_classifier: 0.0604 (0.0557)  loss_box_reg: 0.0783 (0.0853)  loss_objectness: 0.0022 (0.0044)  loss_rpn_box_reg: 0.0036 (0.0069)  time: 4.9471  data: 0.1109
# Epoch: [2]  [100/551]  eta: 0:36:23  lr: 0.005000  loss: 0.1414 (0.1526)  loss_classifier: 0.0570 (0.0564)  loss_box_reg: 0.0772 (0.0853)  loss_objectness: 0.0021 (0.0043)  loss_rpn_box_reg: 0.0029 (0.0066)  time: 4.9286  data: 0.1079
# Epoch: [2]  [110/551]  eta: 0:35:36  lr: 0.005000  loss: 0.1388 (0.1536)  loss_classifier: 0.0533 (0.0573)  loss_box_reg: 0.0829 (0.0859)  loss_objectness: 0.0016 (0.0042)  loss_rpn_box_reg: 0.0029 (0.0063)  time: 4.8712  data: 0.1098
# Epoch: [2]  [120/551]  eta: 0:34:48  lr: 0.005000  loss: 0.1388 (0.1527)  loss_classifier: 0.0519 (0.0571)  loss_box_reg: 0.0817 (0.0845)  loss_objectness: 0.0021 (0.0045)  loss_rpn_box_reg: 0.0038 (0.0066)  time: 4.8630  data: 0.1063
# Epoch: [2]  [130/551]  eta: 0:33:59  lr: 0.005000  loss: 0.1759 (0.1556)  loss_classifier: 0.0588 (0.0584)  loss_box_reg: 0.0817 (0.0863)  loss_objectness: 0.0013 (0.0045)  loss_rpn_box_reg: 0.0050 (0.0065)  time: 4.8437  data: 0.1098
# Epoch: [2]  [140/551]  eta: 0:33:12  lr: 0.005000  loss: 0.1444 (0.1530)  loss_classifier: 0.0658 (0.0581)  loss_box_reg: 0.0803 (0.0844)  loss_objectness: 0.0009 (0.0043)  loss_rpn_box_reg: 0.0026 (0.0061)  time: 4.8611  data: 0.1172
# Epoch: [2]  [150/551]  eta: 0:32:23  lr: 0.005000  loss: 0.1409 (0.1522)  loss_classifier: 0.0548 (0.0581)  loss_box_reg: 0.0726 (0.0841)  loss_objectness: 0.0009 (0.0041)  loss_rpn_box_reg: 0.0020 (0.0059)  time: 4.8520  data: 0.1136
# Epoch: [2]  [160/551]  eta: 0:31:32  lr: 0.005000  loss: 0.1429 (0.1521)  loss_classifier: 0.0474 (0.0576)  loss_box_reg: 0.0802 (0.0845)  loss_objectness: 0.0014 (0.0041)  loss_rpn_box_reg: 0.0027 (0.0059)  time: 4.7967  data: 0.1081
# Epoch: [2]  [170/551]  eta: 0:30:42  lr: 0.005000  loss: 0.1089 (0.1494)  loss_classifier: 0.0414 (0.0567)  loss_box_reg: 0.0606 (0.0828)  loss_objectness: 0.0014 (0.0040)  loss_rpn_box_reg: 0.0037 (0.0058)  time: 4.7545  data: 0.1044
# Epoch: [2]  [180/551]  eta: 0:29:54  lr: 0.005000  loss: 0.1173 (0.1494)  loss_classifier: 0.0449 (0.0567)  loss_box_reg: 0.0606 (0.0829)  loss_objectness: 0.0010 (0.0039)  loss_rpn_box_reg: 0.0035 (0.0058)  time: 4.7979  data: 0.1043
# Epoch: [2]  [190/551]  eta: 0:29:01  lr: 0.005000  loss: 0.1477 (0.1492)  loss_classifier: 0.0523 (0.0566)  loss_box_reg: 0.0730 (0.0827)  loss_objectness: 0.0014 (0.0039)  loss_rpn_box_reg: 0.0043 (0.0060)  time: 4.7457  data: 0.0995
# Epoch: [2]  [200/551]  eta: 0:28:12  lr: 0.005000  loss: 0.1366 (0.1497)  loss_classifier: 0.0509 (0.0569)  loss_box_reg: 0.0764 (0.0829)  loss_objectness: 0.0042 (0.0040)  loss_rpn_box_reg: 0.0043 (0.0059)  time: 4.6887  data: 0.1014
# Epoch: [2]  [210/551]  eta: 0:27:25  lr: 0.005000  loss: 0.1590 (0.1509)  loss_classifier: 0.0529 (0.0570)  loss_box_reg: 0.1022 (0.0840)  loss_objectness: 0.0021 (0.0040)  loss_rpn_box_reg: 0.0040 (0.0059)  time: 4.8339  data: 0.1099
# Epoch: [2]  [220/551]  eta: 0:26:39  lr: 0.005000  loss: 0.1480 (0.1503)  loss_classifier: 0.0564 (0.0569)  loss_box_reg: 0.0764 (0.0836)  loss_objectness: 0.0017 (0.0040)  loss_rpn_box_reg: 0.0028 (0.0058)  time: 4.9463  data: 0.1106
# Epoch: [2]  [230/551]  eta: 0:25:48  lr: 0.005000  loss: 0.1362 (0.1509)  loss_classifier: 0.0572 (0.0571)  loss_box_reg: 0.0822 (0.0840)  loss_objectness: 0.0014 (0.0040)  loss_rpn_box_reg: 0.0026 (0.0059)  time: 4.8075  data: 0.1065
# Epoch: [2]  [240/551]  eta: 0:25:02  lr: 0.005000  loss: 0.1278 (0.1491)  loss_classifier: 0.0420 (0.0564)  loss_box_reg: 0.0631 (0.0827)  loss_objectness: 0.0013 (0.0040)  loss_rpn_box_reg: 0.0029 (0.0059)  time: 4.8205  data: 0.0995
# Epoch: [2]  [250/551]  eta: 0:24:14  lr: 0.005000  loss: 0.1120 (0.1495)  loss_classifier: 0.0408 (0.0564)  loss_box_reg: 0.0626 (0.0833)  loss_objectness: 0.0035 (0.0040)  loss_rpn_box_reg: 0.0029 (0.0059)  time: 4.9361  data: 0.1031
# Epoch: [2]  [260/551]  eta: 0:23:27  lr: 0.005000  loss: 0.1439 (0.1498)  loss_classifier: 0.0539 (0.0564)  loss_box_reg: 0.0795 (0.0836)  loss_objectness: 0.0040 (0.0040)  loss_rpn_box_reg: 0.0036 (0.0058)  time: 4.9062  data: 0.1116
# Epoch: [2]  [270/551]  eta: 0:22:40  lr: 0.005000  loss: 0.1286 (0.1489)  loss_classifier: 0.0435 (0.0558)  loss_box_reg: 0.0713 (0.0832)  loss_objectness: 0.0037 (0.0040)  loss_rpn_box_reg: 0.0025 (0.0059)  time: 4.9433  data: 0.1032
# Epoch: [2]  [280/551]  eta: 0:21:52  lr: 0.005000  loss: 0.1069 (0.1483)  loss_classifier: 0.0434 (0.0558)  loss_box_reg: 0.0603 (0.0827)  loss_objectness: 0.0018 (0.0040)  loss_rpn_box_reg: 0.0022 (0.0058)  time: 4.9204  data: 0.1044
# Epoch: [2]  [290/551]  eta: 0:21:04  lr: 0.005000  loss: 0.1251 (0.1483)  loss_classifier: 0.0518 (0.0557)  loss_box_reg: 0.0576 (0.0828)  loss_objectness: 0.0017 (0.0040)  loss_rpn_box_reg: 0.0023 (0.0058)  time: 4.9011  data: 0.1144
# Epoch: [2]  [300/551]  eta: 0:20:17  lr: 0.005000  loss: 0.1499 (0.1485)  loss_classifier: 0.0529 (0.0557)  loss_box_reg: 0.0888 (0.0831)  loss_objectness: 0.0012 (0.0039)  loss_rpn_box_reg: 0.0026 (0.0058)  time: 4.9411  data: 0.1126
# Epoch: [2]  [310/551]  eta: 0:19:28  lr: 0.005000  loss: 0.1550 (0.1491)  loss_classifier: 0.0592 (0.0560)  loss_box_reg: 0.1057 (0.0835)  loss_objectness: 0.0009 (0.0039)  loss_rpn_box_reg: 0.0036 (0.0058)  time: 4.9179  data: 0.1148
# Epoch: [2]  [320/551]  eta: 0:18:41  lr: 0.005000  loss: 0.1550 (0.1489)  loss_classifier: 0.0547 (0.0558)  loss_box_reg: 0.0926 (0.0835)  loss_objectness: 0.0016 (0.0038)  loss_rpn_box_reg: 0.0040 (0.0058)  time: 4.9323  data: 0.1121
# Epoch: [2]  [330/551]  eta: 0:17:53  lr: 0.005000  loss: 0.1483 (0.1486)  loss_classifier: 0.0474 (0.0558)  loss_box_reg: 0.0811 (0.0832)  loss_objectness: 0.0022 (0.0038)  loss_rpn_box_reg: 0.0033 (0.0058)  time: 4.9627  data: 0.1088
# Epoch: [2]  [340/551]  eta: 0:17:04  lr: 0.005000  loss: 0.1493 (0.1485)  loss_classifier: 0.0552 (0.0558)  loss_box_reg: 0.0787 (0.0829)  loss_objectness: 0.0016 (0.0039)  loss_rpn_box_reg: 0.0041 (0.0060)  time: 4.8440  data: 0.1040
# Epoch: [2]  [350/551]  eta: 0:16:16  lr: 0.005000  loss: 0.1493 (0.1488)  loss_classifier: 0.0552 (0.0558)  loss_box_reg: 0.0828 (0.0831)  loss_objectness: 0.0016 (0.0038)  loss_rpn_box_reg: 0.0036 (0.0060)  time: 4.8785  data: 0.1011
# Epoch: [2]  [360/551]  eta: 0:15:27  lr: 0.005000  loss: 0.1228 (0.1485)  loss_classifier: 0.0453 (0.0559)  loss_box_reg: 0.0684 (0.0830)  loss_objectness: 0.0015 (0.0038)  loss_rpn_box_reg: 0.0027 (0.0060)  time: 4.9299  data: 0.1071
# Epoch: [2]  [370/551]  eta: 0:14:40  lr: 0.005000  loss: 0.1253 (0.1485)  loss_classifier: 0.0462 (0.0558)  loss_box_reg: 0.0684 (0.0831)  loss_objectness: 0.0013 (0.0038)  loss_rpn_box_reg: 0.0017 (0.0059)  time: 4.9437  data: 0.1127
# Epoch: [2]  [380/551]  eta: 0:13:51  lr: 0.005000  loss: 0.1516 (0.1494)  loss_classifier: 0.0461 (0.0561)  loss_box_reg: 0.0963 (0.0836)  loss_objectness: 0.0018 (0.0038)  loss_rpn_box_reg: 0.0027 (0.0059)  time: 4.9297  data: 0.1095
# Epoch: [2]  [390/551]  eta: 0:13:03  lr: 0.005000  loss: 0.1671 (0.1499)  loss_classifier: 0.0616 (0.0564)  loss_box_reg: 0.0906 (0.0839)  loss_objectness: 0.0019 (0.0038)  loss_rpn_box_reg: 0.0030 (0.0059)  time: 4.8839  data: 0.1066
# Epoch: [2]  [400/551]  eta: 0:12:13  lr: 0.005000  loss: 0.1478 (0.1498)  loss_classifier: 0.0549 (0.0563)  loss_box_reg: 0.0833 (0.0838)  loss_objectness: 0.0016 (0.0038)  loss_rpn_box_reg: 0.0027 (0.0059)  time: 4.8217  data: 0.1096
# Epoch: [2]  [410/551]  eta: 0:11:25  lr: 0.005000  loss: 0.1457 (0.1500)  loss_classifier: 0.0515 (0.0564)  loss_box_reg: 0.0856 (0.0837)  loss_objectness: 0.0035 (0.0039)  loss_rpn_box_reg: 0.0031 (0.0060)  time: 4.7761  data: 0.1043
# Epoch: [2]  [420/551]  eta: 0:10:36  lr: 0.005000  loss: 0.1583 (0.1499)  loss_classifier: 0.0587 (0.0565)  loss_box_reg: 0.0856 (0.0837)  loss_objectness: 0.0019 (0.0039)  loss_rpn_box_reg: 0.0037 (0.0060)  time: 4.8326  data: 0.1006
# Epoch: [2]  [430/551]  eta: 0:09:48  lr: 0.005000  loss: 0.1710 (0.1511)  loss_classifier: 0.0597 (0.0569)  loss_box_reg: 0.1037 (0.0843)  loss_objectness: 0.0019 (0.0039)  loss_rpn_box_reg: 0.0038 (0.0060)  time: 4.9016  data: 0.1066
# Epoch: [2]  [440/551]  eta: 0:09:00  lr: 0.005000  loss: 0.1845 (0.1514)  loss_classifier: 0.0632 (0.0569)  loss_box_reg: 0.1037 (0.0846)  loss_objectness: 0.0017 (0.0038)  loss_rpn_box_reg: 0.0059 (0.0061)  time: 5.0001  data: 0.1097
# Epoch: [2]  [450/551]  eta: 0:08:11  lr: 0.005000  loss: 0.1372 (0.1507)  loss_classifier: 0.0500 (0.0565)  loss_box_reg: 0.0859 (0.0843)  loss_objectness: 0.0014 (0.0038)  loss_rpn_box_reg: 0.0043 (0.0061)  time: 5.0136  data: 0.1064
# Epoch: [2]  [460/551]  eta: 0:07:22  lr: 0.005000  loss: 0.1355 (0.1799)  loss_classifier: 0.0449 (0.0564)  loss_box_reg: 0.0572 (0.0839)  loss_objectness: 0.0039 (0.0093)  loss_rpn_box_reg: 0.0034 (0.0303)  time: 4.7860  data: 0.1030
# Epoch: [2]  [470/551]  eta: 0:06:33  lr: 0.005000  loss: 0.1217 (0.1788)  loss_classifier: 0.0411 (0.0559)  loss_box_reg: 0.0660 (0.0837)  loss_objectness: 0.0133 (0.0094)  loss_rpn_box_reg: 0.0025 (0.0298)  time: 4.7169  data: 0.1094
# Epoch: [2]  [480/551]  eta: 0:05:45  lr: 0.005000  loss: 0.1164 (0.1778)  loss_classifier: 0.0310 (0.0556)  loss_box_reg: 0.0660 (0.0833)  loss_objectness: 0.0138 (0.0095)  loss_rpn_box_reg: 0.0024 (0.0293)  time: 5.0021  data: 0.1144
# Epoch: [2]  [490/551]  eta: 0:04:57  lr: 0.005000  loss: 0.0989 (0.1766)  loss_classifier: 0.0319 (0.0554)  loss_box_reg: 0.0444 (0.0829)  loss_objectness: 0.0060 (0.0095)  loss_rpn_box_reg: 0.0035 (0.0288)  time: 5.0748  data: 0.1125
# Epoch: [2]  [500/551]  eta: 0:04:08  lr: 0.005000  loss: 0.0919 (0.1750)  loss_classifier: 0.0376 (0.0550)  loss_box_reg: 0.0444 (0.0822)  loss_objectness: 0.0042 (0.0095)  loss_rpn_box_reg: 0.0023 (0.0284)  time: 4.9398  data: 0.1091
# Epoch: [2]  [510/551]  eta: 0:03:19  lr: 0.005000  loss: 0.1121 (0.1747)  loss_classifier: 0.0380 (0.0550)  loss_box_reg: 0.0599 (0.0824)  loss_objectness: 0.0027 (0.0094)  loss_rpn_box_reg: 0.0032 (0.0279)  time: 4.9332  data: 0.1082
# Epoch: [2]  [520/551]  eta: 0:02:31  lr: 0.005000  loss: 0.1319 (0.1737)  loss_classifier: 0.0491 (0.0548)  loss_box_reg: 0.0760 (0.0821)  loss_objectness: 0.0017 (0.0092)  loss_rpn_box_reg: 0.0022 (0.0274)  time: 5.0181  data: 0.1159
# Epoch: [2]  [530/551]  eta: 0:01:42  lr: 0.005000  loss: 0.1122 (0.1725)  loss_classifier: 0.0371 (0.0546)  loss_box_reg: 0.0568 (0.0817)  loss_objectness: 0.0016 (0.0092)  loss_rpn_box_reg: 0.0021 (0.0271)  time: 4.9549  data: 0.1140
# Epoch: [2]  [540/551]  eta: 0:00:53  lr: 0.005000  loss: 0.1092 (0.1717)  loss_classifier: 0.0367 (0.0544)  loss_box_reg: 0.0603 (0.0816)  loss_objectness: 0.0013 (0.0091)  loss_rpn_box_reg: 0.0021 (0.0266)  time: 4.8921  data: 0.1078
# Epoch: [2]  [550/551]  eta: 0:00:04  lr: 0.005000  loss: 0.1197 (0.1854)  loss_classifier: 0.0393 (0.0541)  loss_box_reg: 0.0717 (0.0813)  loss_objectness: 0.0013 (0.0125)  loss_rpn_box_reg: 0.0022 (0.0375)  time: 4.9121  data: 0.1056
# Epoch: [2] Total time: 0:44:47 (4.8776 s / it)
# Epoch: [3]  [  0/551]  eta: 0:47:59  lr: 0.000500  loss: 0.0646 (0.0646)  loss_classifier: 0.0194 (0.0194)  loss_box_reg: 0.0275 (0.0275)  loss_objectness: 0.0138 (0.0138)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 5.2261  data: 0.0891
# Epoch: [3]  [ 10/551]  eta: 0:45:28  lr: 0.000500  loss: 0.0824 (0.0892)  loss_classifier: 0.0279 (0.0313)  loss_box_reg: 0.0330 (0.0416)  loss_objectness: 0.0052 (0.0087)  loss_rpn_box_reg: 0.0039 (0.0075)  time: 5.0439  data: 0.0968
# Epoch: [3]  [ 20/551]  eta: 0:44:35  lr: 0.000500  loss: 0.0824 (0.0891)  loss_classifier: 0.0279 (0.0334)  loss_box_reg: 0.0370 (0.0426)  loss_objectness: 0.0034 (0.0074)  loss_rpn_box_reg: 0.0020 (0.0058)  time: 5.0289  data: 0.1009
# Epoch: [3]  [ 30/551]  eta: 0:43:40  lr: 0.000500  loss: 0.0936 (0.0960)  loss_classifier: 0.0317 (0.0353)  loss_box_reg: 0.0439 (0.0481)  loss_objectness: 0.0034 (0.0071)  loss_rpn_box_reg: 0.0020 (0.0056)  time: 5.0221  data: 0.1071
# Epoch: [3]  [ 40/551]  eta: 0:42:33  lr: 0.000500  loss: 0.0764 (0.0915)  loss_classifier: 0.0270 (0.0338)  loss_box_reg: 0.0364 (0.0452)  loss_objectness: 0.0024 (0.0069)  loss_rpn_box_reg: 0.0020 (0.0055)  time: 4.9518  data: 0.1063
# Epoch: [3]  [ 50/551]  eta: 0:41:25  lr: 0.000500  loss: 0.0654 (0.0876)  loss_classifier: 0.0259 (0.0324)  loss_box_reg: 0.0303 (0.0431)  loss_objectness: 0.0024 (0.0069)  loss_rpn_box_reg: 0.0020 (0.0052)  time: 4.8523  data: 0.1014
# Epoch: [3]  [ 60/551]  eta: 0:40:34  lr: 0.000500  loss: 0.0883 (0.0929)  loss_classifier: 0.0346 (0.0342)  loss_box_reg: 0.0488 (0.0470)  loss_objectness: 0.0024 (0.0065)  loss_rpn_box_reg: 0.0016 (0.0053)  time: 4.8836  data: 0.1068
# Epoch: [3]  [ 70/551]  eta: 0:39:37  lr: 0.000500  loss: 0.0883 (0.0905)  loss_classifier: 0.0318 (0.0328)  loss_box_reg: 0.0530 (0.0461)  loss_objectness: 0.0021 (0.0064)  loss_rpn_box_reg: 0.0017 (0.0051)  time: 4.8951  data: 0.1062
# Epoch: [3]  [ 80/551]  eta: 0:38:59  lr: 0.000500  loss: 0.0834 (0.0906)  loss_classifier: 0.0318 (0.0335)  loss_box_reg: 0.0391 (0.0459)  loss_objectness: 0.0021 (0.0063)  loss_rpn_box_reg: 0.0016 (0.0050)  time: 4.9891  data: 0.1053
# Epoch: [3]  [ 90/551]  eta: 0:38:24  lr: 0.000500  loss: 0.0963 (0.0918)  loss_classifier: 0.0352 (0.0344)  loss_box_reg: 0.0444 (0.0467)  loss_objectness: 0.0026 (0.0060)  loss_rpn_box_reg: 0.0016 (0.0047)  time: 5.2044  data: 0.1140
# Epoch: [3]  [100/551]  eta: 0:37:36  lr: 0.000500  loss: 0.0984 (0.0917)  loss_classifier: 0.0359 (0.0342)  loss_box_reg: 0.0434 (0.0466)  loss_objectness: 0.0026 (0.0062)  loss_rpn_box_reg: 0.0019 (0.0046)  time: 5.1529  data: 0.1123
# Epoch: [3]  [110/551]  eta: 0:36:52  lr: 0.000500  loss: 0.1010 (0.0934)  loss_classifier: 0.0375 (0.0351)  loss_box_reg: 0.0463 (0.0475)  loss_objectness: 0.0019 (0.0060)  loss_rpn_box_reg: 0.0025 (0.0048)  time: 5.0999  data: 0.1073
# Epoch: [3]  [120/551]  eta: 0:36:02  lr: 0.000500  loss: 0.0965 (0.0925)  loss_classifier: 0.0351 (0.0348)  loss_box_reg: 0.0456 (0.0469)  loss_objectness: 0.0019 (0.0060)  loss_rpn_box_reg: 0.0021 (0.0048)  time: 5.0940  data: 0.1077
# Epoch: [3]  [130/551]  eta: 0:35:23  lr: 0.000500  loss: 0.0797 (0.0915)  loss_classifier: 0.0267 (0.0343)  loss_box_reg: 0.0359 (0.0460)  loss_objectness: 0.0074 (0.0064)  loss_rpn_box_reg: 0.0030 (0.0049)  time: 5.1882  data: 0.1022
# Epoch: [3]  [140/551]  eta: 0:34:30  lr: 0.000500  loss: 0.0822 (0.0926)  loss_classifier: 0.0333 (0.0349)  loss_box_reg: 0.0453 (0.0469)  loss_objectness: 0.0027 (0.0061)  loss_rpn_box_reg: 0.0030 (0.0047)  time: 5.1536  data: 0.1065
# Epoch: [3]  [150/551]  eta: 0:33:53  lr: 0.000500  loss: 0.1000 (0.0932)  loss_classifier: 0.0388 (0.0349)  loss_box_reg: 0.0586 (0.0476)  loss_objectness: 0.0011 (0.0059)  loss_rpn_box_reg: 0.0024 (0.0047)  time: 5.2514  data: 0.1165
# Epoch: [3]  [160/551]  eta: 0:33:10  lr: 0.000500  loss: 0.0960 (0.0938)  loss_classifier: 0.0345 (0.0352)  loss_box_reg: 0.0552 (0.0482)  loss_objectness: 0.0010 (0.0057)  loss_rpn_box_reg: 0.0020 (0.0047)  time: 5.4614  data: 0.1180
# Epoch: [3]  [170/551]  eta: 0:32:31  lr: 0.000500  loss: 0.0765 (0.0923)  loss_classifier: 0.0344 (0.0348)  loss_box_reg: 0.0409 (0.0474)  loss_objectness: 0.0009 (0.0056)  loss_rpn_box_reg: 0.0014 (0.0045)  time: 5.5155  data: 0.1176
# Epoch: [3]  [180/551]  eta: 0:31:41  lr: 0.000500  loss: 0.0762 (0.0928)  loss_classifier: 0.0312 (0.0349)  loss_box_reg: 0.0389 (0.0478)  loss_objectness: 0.0012 (0.0056)  loss_rpn_box_reg: 0.0021 (0.0045)  time: 5.4107  data: 0.1119
# Epoch: [3]  [190/551]  eta: 0:30:48  lr: 0.000500  loss: 0.0945 (0.0921)  loss_classifier: 0.0282 (0.0347)  loss_box_reg: 0.0402 (0.0473)  loss_objectness: 0.0062 (0.0056)  loss_rpn_box_reg: 0.0021 (0.0045)  time: 5.1028  data: 0.1051
# Epoch: [3]  [200/551]  eta: 0:29:57  lr: 0.000500  loss: 0.0786 (0.1413)  loss_classifier: 0.0282 (0.0346)  loss_box_reg: 0.0394 (0.0472)  loss_objectness: 0.0023 (0.0141)  loss_rpn_box_reg: 0.0017 (0.0453)  time: 5.0792  data: 0.1032
# Epoch: [3]  [210/551]  eta: 0:29:05  lr: 0.000500  loss: 0.0828 (0.1389)  loss_classifier: 0.0313 (0.0346)  loss_box_reg: 0.0461 (0.0473)  loss_objectness: 0.0017 (0.0137)  loss_rpn_box_reg: 0.0017 (0.0433)  time: 5.0898  data: 0.1061
# Epoch: [3]  [220/551]  eta: 0:28:16  lr: 0.000500  loss: 0.0886 (0.1371)  loss_classifier: 0.0312 (0.0348)  loss_box_reg: 0.0485 (0.0476)  loss_objectness: 0.0018 (0.0132)  loss_rpn_box_reg: 0.0019 (0.0415)  time: 5.1619  data: 0.1086
# Epoch: [3]  [230/551]  eta: 0:27:23  lr: 0.000500  loss: 0.0865 (0.1826)  loss_classifier: 0.0289 (0.0344)  loss_box_reg: 0.0392 (0.0469)  loss_objectness: 0.0042 (0.0189)  loss_rpn_box_reg: 0.0024 (0.0823)  time: 5.1364  data: 0.0995
# Epoch: [3]  [240/551]  eta: 0:49:53  lr: 0.000500  loss: 0.0754 (0.2034)  loss_classifier: 0.0227 (0.0340)  loss_box_reg: 0.0317 (0.0463)  loss_objectness: 0.0058 (0.0248)  loss_rpn_box_reg: 0.0024 (0.0982)  time: 59.3462  data: 0.0936
# Epoch: [3]  [250/551]  eta: 0:59:06  lr: 0.000500  loss: 0.0807 (0.1990)  loss_classifier: 0.0240 (0.0341)  loss_box_reg: 0.0367 (0.0462)  loss_objectness: 0.0058 (0.0241)  loss_rpn_box_reg: 0.0024 (0.0946)  time: 88.7334  data: 0.0955
# Epoch: [3]  [260/551]  eta: 0:55:57  lr: 0.000500  loss: 0.0754 (0.1945)  loss_classifier: 0.0266 (0.0341)  loss_box_reg: 0.0325 (0.0460)  loss_objectness: 0.0026 (0.0233)  loss_rpn_box_reg: 0.0020 (0.0911)  time: 34.5816  data: 0.1016
# Epoch: [3]  [270/551]  eta: 0:52:56  lr: 0.000500  loss: 0.0714 (0.3087)  loss_classifier: 0.0263 (0.0341)  loss_box_reg: 0.0309 (0.0456)  loss_objectness: 0.0021 (0.0378)  loss_rpn_box_reg: 0.0019 (0.1912)  time: 5.2919  data: 0.1103
# Epoch: [3]  [280/551]  eta: 0:50:05  lr: 0.000500  loss: 0.0902 (0.3009)  loss_classifier: 0.0263 (0.0341)  loss_box_reg: 0.0395 (0.0456)  loss_objectness: 0.0037 (0.0367)  loss_rpn_box_reg: 0.0018 (0.1845)  time: 5.2447  data: 0.1122
# Epoch: [3]  [290/551]  eta: 0:47:21  lr: 0.000500  loss: 0.0926 (0.2940)  loss_classifier: 0.0304 (0.0342)  loss_box_reg: 0.0470 (0.0458)  loss_objectness: 0.0041 (0.0357)  loss_rpn_box_reg: 0.0020 (0.1783)  time: 5.2225  data: 0.1062
# Epoch: [3]  [300/551]  eta: 0:44:42  lr: 0.000500  loss: 0.0836 (0.2873)  loss_classifier: 0.0263 (0.0340)  loss_box_reg: 0.0410 (0.0459)  loss_objectness: 0.0067 (0.0349)  loss_rpn_box_reg: 0.0020 (0.1726)  time: 5.0304  data: 0.0999
# Epoch: [3]  [310/551]  eta: 0:42:13  lr: 0.000500  loss: 0.0874 (0.2812)  loss_classifier: 0.0290 (0.0341)  loss_box_reg: 0.0397 (0.0460)  loss_objectness: 0.0031 (0.0339)  loss_rpn_box_reg: 0.0026 (0.1672)  time: 5.0950  data: 0.1082
# Epoch: [3]  [320/551]  eta: 0:39:48  lr: 0.000500  loss: 0.0843 (0.2749)  loss_classifier: 0.0313 (0.0340)  loss_box_reg: 0.0376 (0.0458)  loss_objectness: 0.0018 (0.0330)  loss_rpn_box_reg: 0.0019 (0.1621)  time: 5.1203  data: 0.1104
# ...
# Epoch: [3]  [530/551]  eta: 0:03:25  lr: 0.000500  loss: 0.0667 (0.2485)  loss_classifier: 0.0270 (0.0332)  loss_box_reg: 0.0381 (0.0438)  loss_objectness: 0.0016 (0.0298)  loss_rpn_box_reg: 0.0014 (0.1418)  time: 5.3857  data: 0.1134
# Epoch: [3]  [540/551]  eta: 0:01:46  lr: 0.000500  loss: 0.0789 (0.2456)  loss_classifier: 0.0319 (0.0332)  loss_box_reg: 0.0394 (0.0438)  loss_objectness: 0.0016 (0.0293)  loss_rpn_box_reg: 0.0023 (0.1393)  time: 5.5560  data: 0.1136
# Epoch: [3]  [550/551]  eta: 0:00:09  lr: 0.000500  loss: 0.0843 (0.2428)  loss_classifier: 0.0319 (0.0333)  loss_box_reg: 0.0440 (0.0438)  loss_objectness: 0.0018 (0.0289)  loss_rpn_box_reg: 0.0018 (0.1368)  time: 5.4943  data: 0.1156
# Epoch: [3] Total time: 1:28:27 (9.6318 s / it)
# Epoch: [4]  [  0/551]  eta: 0:48:29  lr: 0.000500  loss: 0.1007 (0.1007)  loss_classifier: 0.0309 (0.0309)  loss_box_reg: 0.0672 (0.0672)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 5.2811  data: 0.1377
# Epoch: [4]  [ 10/551]  eta: 0:48:30  lr: 0.000500  loss: 0.1007 (0.0922)  loss_classifier: 0.0338 (0.0334)  loss_box_reg: 0.0568 (0.0513)  loss_objectness: 0.0013 (0.0031)  loss_rpn_box_reg: 0.0016 (0.0043)  time: 5.3803  data: 0.1158
# Epoch: [4]  [ 20/551]  eta: 0:50:06  lr: 0.000500  loss: 0.0680 (0.0792)  loss_classifier: 0.0302 (0.0299)  loss_box_reg: 0.0324 (0.0425)  loss_objectness: 0.0017 (0.0037)  loss_rpn_box_reg: 0.0014 (0.0030)  time: 5.6812  data: 0.1145
# Epoch: [4]  [ 30/551]  eta: 0:49:22  lr: 0.000500  loss: 0.0611 (0.0799)  loss_classifier: 0.0220 (0.0299)  loss_box_reg: 0.0283 (0.0405)  loss_objectness: 0.0030 (0.0051)  loss_rpn_box_reg: 0.0012 (0.0044)  time: 5.8553  data: 0.1084
# Epoch: [4]  [ 40/551]  eta: 0:48:35  lr: 0.000500  loss: 0.0838 (0.0813)  loss_classifier: 0.0298 (0.0307)  loss_box_reg: 0.0411 (0.0417)  loss_objectness: 0.0018 (0.0046)  loss_rpn_box_reg: 0.0021 (0.0043)  time: 5.7506  data: 0.1071
# Epoch: [4]  [ 50/551]  eta: 0:47:03  lr: 0.000500  loss: 0.0787 (0.0784)  loss_classifier: 0.0318 (0.0302)  loss_box_reg: 0.0418 (0.0397)  loss_objectness: 0.0017 (0.0045)  loss_rpn_box_reg: 0.0022 (0.0041)  time: 5.5569  data: 0.1119
# Epoch: [4]  [ 60/551]  eta: 0:45:39  lr: 0.000500  loss: 0.0633 (0.0774)  loss_classifier: 0.0304 (0.0297)  loss_box_reg: 0.0341 (0.0395)  loss_objectness: 0.0013 (0.0043)  loss_rpn_box_reg: 0.0019 (0.0039)  time: 5.3188  data: 0.1129
# Epoch: [4]  [ 70/551]  eta: 0:44:53  lr: 0.000500  loss: 0.0685 (0.0769)  loss_classifier: 0.0246 (0.0292)  loss_box_reg: 0.0341 (0.0392)  loss_objectness: 0.0013 (0.0046)  loss_rpn_box_reg: 0.0017 (0.0039)  time: 5.5106  data: 0.1097
# Epoch: [4]  [ 80/551]  eta: 0:44:03  lr: 0.000500  loss: 0.0648 (0.0770)  loss_classifier: 0.0232 (0.0292)  loss_box_reg: 0.0311 (0.0394)  loss_objectness: 0.0017 (0.0045)  loss_rpn_box_reg: 0.0016 (0.0037)  time: 5.7156  data: 0.1072
# Epoch: [4]  [ 90/551]  eta: 0:42:57  lr: 0.000500  loss: 0.0566 (0.0756)  loss_classifier: 0.0232 (0.0287)  loss_box_reg: 0.0277 (0.0387)  loss_objectness: 0.0016 (0.0045)  loss_rpn_box_reg: 0.0015 (0.0036)  time: 5.5621  data: 0.1113
# Epoch: [4]  [100/551]  eta: 0:41:42  lr: 0.000500  loss: 0.0629 (0.0758)  loss_classifier: 0.0233 (0.0290)  loss_box_reg: 0.0291 (0.0388)  loss_objectness: 0.0015 (0.0044)  loss_rpn_box_reg: 0.0015 (0.0035)  time: 5.2961  data: 0.1077
# Epoch: [4]  [110/551]  eta: 0:40:41  lr: 0.000500  loss: 0.0788 (0.0766)  loss_classifier: 0.0267 (0.0294)  loss_box_reg: 0.0411 (0.0392)  loss_objectness: 0.0020 (0.0045)  loss_rpn_box_reg: 0.0019 (0.0036)  time: 5.2853  data: 0.1039
# Epoch: [4]  [120/551]  eta: 0:39:37  lr: 0.000500  loss: 0.0788 (0.0775)  loss_classifier: 0.0276 (0.0296)  loss_box_reg: 0.0465 (0.0398)  loss_objectness: 0.0026 (0.0045)  loss_rpn_box_reg: 0.0019 (0.0035)  time: 5.3488  data: 0.1092
# Epoch: [4]  [130/551]  eta: 0:38:20  lr: 0.000500  loss: 0.0772 (0.0768)  loss_classifier: 0.0287 (0.0296)  loss_box_reg: 0.0394 (0.0397)  loss_objectness: 0.0010 (0.0043)  loss_rpn_box_reg: 0.0013 (0.0033)  time: 5.0548  data: 0.1166
# Epoch: [4]  [140/551]  eta: 0:37:14  lr: 0.000500  loss: 0.0750 (0.0767)  loss_classifier: 0.0287 (0.0298)  loss_box_reg: 0.0342 (0.0394)  loss_objectness: 0.0008 (0.0042)  loss_rpn_box_reg: 0.0013 (0.0033)  time: 4.9525  data: 0.1158
# Epoch: [4]  [150/551]  eta: 0:36:13  lr: 0.000500  loss: 0.0785 (0.0773)  loss_classifier: 0.0317 (0.0300)  loss_box_reg: 0.0330 (0.0394)  loss_objectness: 0.0042 (0.0044)  loss_rpn_box_reg: 0.0017 (0.0034)  time: 5.1397  data: 0.1090
# Epoch: [4]  [160/551]  eta: 0:35:12  lr: 0.000500  loss: 0.0734 (0.0771)  loss_classifier: 0.0273 (0.0299)  loss_box_reg: 0.0306 (0.0392)  loss_objectness: 0.0042 (0.0045)  loss_rpn_box_reg: 0.0017 (0.0035)  time: 5.1708  data: 0.1119
# Epoch: [4]  [170/551]  eta: 0:34:17  lr: 0.000500  loss: 0.0698 (0.0767)  loss_classifier: 0.0248 (0.0297)  loss_box_reg: 0.0306 (0.0387)  loss_objectness: 0.0025 (0.0047)  loss_rpn_box_reg: 0.0011 (0.0036)  time: 5.2424  data: 0.1128
# Epoch: [4]  [180/551]  eta: 0:33:19  lr: 0.000500  loss: 0.0738 (0.0773)  loss_classifier: 0.0256 (0.0299)  loss_box_reg: 0.0363 (0.0391)  loss_objectness: 0.0012 (0.0047)  loss_rpn_box_reg: 0.0017 (0.0036)  time: 5.2875  data: 0.1078
# Epoch: [4]  [190/551]  eta: 0:32:22  lr: 0.000500  loss: 0.0669 (0.0766)  loss_classifier: 0.0277 (0.0299)  loss_box_reg: 0.0290 (0.0388)  loss_objectness: 0.0009 (0.0044)  loss_rpn_box_reg: 0.0014 (0.0035)  time: 5.2133  data: 0.1105
# Epoch: [4]  [200/551]  eta: 0:31:23  lr: 0.000500  loss: 0.0547 (0.0760)  loss_classifier: 0.0211 (0.0296)  loss_box_reg: 0.0259 (0.0383)  loss_objectness: 0.0009 (0.0045)  loss_rpn_box_reg: 0.0011 (0.0036)  time: 5.1375  data: 0.1055
# Epoch: [4]  [210/551]  eta: 0:30:20  lr: 0.000500  loss: 0.0635 (0.0761)  loss_classifier: 0.0242 (0.0297)  loss_box_reg: 0.0318 (0.0385)  loss_objectness: 0.0016 (0.0044)  loss_rpn_box_reg: 0.0017 (0.0035)  time: 4.9402  data: 0.1052
# Epoch: [4]  [220/551]  eta: 0:29:19  lr: 0.000500  loss: 0.0776 (0.0768)  loss_classifier: 0.0326 (0.0303)  loss_box_reg: 0.0373 (0.0387)  loss_objectness: 0.0010 (0.0043)  loss_rpn_box_reg: 0.0018 (0.0035)  time: 4.8114  data: 0.1146
# Epoch: [4]  [230/551]  eta: 0:28:20  lr: 0.000500  loss: 0.0772 (0.0761)  loss_classifier: 0.0313 (0.0300)  loss_box_reg: 0.0373 (0.0383)  loss_objectness: 0.0010 (0.0043)  loss_rpn_box_reg: 0.0020 (0.0035)  time: 4.8547  data: 0.1117
# Epoch: [4]  [240/551]  eta: 0:27:22  lr: 0.000500  loss: 0.0667 (0.0762)  loss_classifier: 0.0257 (0.0300)  loss_box_reg: 0.0346 (0.0384)  loss_objectness: 0.0009 (0.0043)  loss_rpn_box_reg: 0.0014 (0.0035)  time: 4.8898  data: 0.1090
# Epoch: [4]  [250/551]  eta: 0:26:22  lr: 0.000500  loss: 0.0698 (0.0759)  loss_classifier: 0.0231 (0.0297)  loss_box_reg: 0.0346 (0.0381)  loss_objectness: 0.0016 (0.0045)  loss_rpn_box_reg: 0.0020 (0.0035)  time: 4.7956  data: 0.1044
# Epoch: [4]  [260/551]  eta: 0:25:24  lr: 0.000500  loss: 0.0708 (0.0764)  loss_classifier: 0.0226 (0.0300)  loss_box_reg: 0.0336 (0.0383)  loss_objectness: 0.0046 (0.0045)  loss_rpn_box_reg: 0.0023 (0.0036)  time: 4.7381  data: 0.0988
# Epoch: [4]  [270/551]  eta: 0:24:25  lr: 0.000500  loss: 0.0918 (0.0768)  loss_classifier: 0.0302 (0.0301)  loss_box_reg: 0.0361 (0.0386)  loss_objectness: 0.0017 (0.0045)  loss_rpn_box_reg: 0.0019 (0.0037)  time: 4.7215  data: 0.0992
# Epoch: [4]  [280/551]  eta: 0:23:29  lr: 0.000500  loss: 0.0843 (0.0777)  loss_classifier: 0.0349 (0.0306)  loss_box_reg: 0.0416 (0.0390)  loss_objectness: 0.0011 (0.0044)  loss_rpn_box_reg: 0.0018 (0.0037)  time: 4.7165  data: 0.1078
# Epoch: [4]  [290/551]  eta: 0:22:33  lr: 0.000500  loss: 0.0843 (0.0778)  loss_classifier: 0.0364 (0.0306)  loss_box_reg: 0.0420 (0.0390)  loss_objectness: 0.0008 (0.0044)  loss_rpn_box_reg: 0.0016 (0.0038)  time: 4.7366  data: 0.1141
# Epoch: [4]  [300/551]  eta: 0:21:38  lr: 0.000500  loss: 0.0832 (0.0779)  loss_classifier: 0.0290 (0.0306)  loss_box_reg: 0.0437 (0.0393)  loss_objectness: 0.0009 (0.0043)  loss_rpn_box_reg: 0.0016 (0.0037)  time: 4.7620  data: 0.1102
# Epoch: [4]  [310/551]  eta: 0:20:43  lr: 0.000500  loss: 0.0773 (0.0779)  loss_classifier: 0.0258 (0.0306)  loss_box_reg: 0.0376 (0.0392)  loss_objectness: 0.0009 (0.0043)  loss_rpn_box_reg: 0.0016 (0.0037)  time: 4.7849  data: 0.1072
# Epoch: [4]  [320/551]  eta: 0:19:49  lr: 0.000500  loss: 0.0773 (0.0779)  loss_classifier: 0.0280 (0.0307)  loss_box_reg: 0.0376 (0.0392)  loss_objectness: 0.0037 (0.0043)  loss_rpn_box_reg: 0.0018 (0.0037)  time: 4.8067  data: 0.1060
# Epoch: [4]  [330/551]  eta: 0:18:55  lr: 0.000500  loss: 0.0784 (0.0778)  loss_classifier: 0.0278 (0.0305)  loss_box_reg: 0.0400 (0.0391)  loss_objectness: 0.0043 (0.0043)  loss_rpn_box_reg: 0.0018 (0.0038)  time: 4.7915  data: 0.1042
# Epoch: [4]  [340/551]  eta: 0:18:02  lr: 0.000500  loss: 0.0742 (0.0777)  loss_classifier: 0.0278 (0.0304)  loss_box_reg: 0.0300 (0.0389)  loss_objectness: 0.0013 (0.0044)  loss_rpn_box_reg: 0.0020 (0.0039)  time: 4.7959  data: 0.1014
# Epoch: [4]  [350/551]  eta: 0:17:08  lr: 0.000500  loss: 0.0742 (0.0774)  loss_classifier: 0.0248 (0.0304)  loss_box_reg: 0.0293 (0.0388)  loss_objectness: 0.0011 (0.0043)  loss_rpn_box_reg: 0.0014 (0.0039)  time: 4.8339  data: 0.1092
# Epoch: [4]  [360/551]  eta: 0:16:16  lr: 0.000500  loss: 0.0664 (0.0771)  loss_classifier: 0.0248 (0.0303)  loss_box_reg: 0.0293 (0.0388)  loss_objectness: 0.0005 (0.0042)  loss_rpn_box_reg: 0.0014 (0.0038)  time: 4.7961  data: 0.1163
# Epoch: [4]  [370/551]  eta: 0:15:23  lr: 0.000500  loss: 0.0748 (0.0775)  loss_classifier: 0.0271 (0.0304)  loss_box_reg: 0.0391 (0.0389)  loss_objectness: 0.0011 (0.0042)  loss_rpn_box_reg: 0.0019 (0.0040)  time: 4.8331  data: 0.1071
# Epoch: [4]  [380/551]  eta: 0:14:30  lr: 0.000500  loss: 0.0779 (0.0776)  loss_classifier: 0.0287 (0.0303)  loss_box_reg: 0.0385 (0.0391)  loss_objectness: 0.0011 (0.0042)  loss_rpn_box_reg: 0.0020 (0.0040)  time: 4.7597  data: 0.1004
# Epoch: [4]  [390/551]  eta: 0:13:38  lr: 0.000500  loss: 0.0715 (0.0776)  loss_classifier: 0.0260 (0.0302)  loss_box_reg: 0.0356 (0.0391)  loss_objectness: 0.0028 (0.0043)  loss_rpn_box_reg: 0.0019 (0.0040)  time: 4.7719  data: 0.1022
# Epoch: [4]  [400/551]  eta: 0:12:46  lr: 0.000500  loss: 0.0766 (0.0776)  loss_classifier: 0.0280 (0.0303)  loss_box_reg: 0.0383 (0.0390)  loss_objectness: 0.0042 (0.0043)  loss_rpn_box_reg: 0.0017 (0.0039)  time: 4.8256  data: 0.1059
# Epoch: [4]  [410/551]  eta: 0:11:54  lr: 0.000500  loss: 0.0773 (0.0774)  loss_classifier: 0.0292 (0.0304)  loss_box_reg: 0.0355 (0.0388)  loss_objectness: 0.0010 (0.0043)  loss_rpn_box_reg: 0.0016 (0.0039)  time: 4.6978  data: 0.1052
# Epoch: [4]  [420/551]  eta: 0:11:02  lr: 0.000500  loss: 0.0684 (0.0774)  loss_classifier: 0.0292 (0.0304)  loss_box_reg: 0.0331 (0.0388)  loss_objectness: 0.0007 (0.0042)  loss_rpn_box_reg: 0.0018 (0.0039)  time: 4.6851  data: 0.1085
# Epoch: [4]  [430/551]  eta: 0:10:11  lr: 0.000500  loss: 0.0678 (0.1064)  loss_classifier: 0.0253 (0.0303)  loss_box_reg: 0.0316 (0.0385)  loss_objectness: 0.0008 (0.0082)  loss_rpn_box_reg: 0.0015 (0.0294)  time: 4.7610  data: 0.1055
# Epoch: [4]  [440/551]  eta: 0:09:20  lr: 0.000500  loss: 0.0595 (0.1054)  loss_classifier: 0.0242 (0.0301)  loss_box_reg: 0.0316 (0.0383)  loss_objectness: 0.0008 (0.0081)  loss_rpn_box_reg: 0.0014 (0.0288)  time: 4.8902  data: 0.1015
# Epoch: [4]  [450/551]  eta: 0:08:30  lr: 0.000500  loss: 0.0731 (0.1049)  loss_classifier: 0.0264 (0.0302)  loss_box_reg: 0.0375 (0.0384)  loss_objectness: 0.0009 (0.0080)  loss_rpn_box_reg: 0.0018 (0.0283)  time: 4.9765  data: 0.1087
# Epoch: [4]  [460/551]  eta: 0:07:39  lr: 0.000500  loss: 0.0857 (0.1048)  loss_classifier: 0.0311 (0.0304)  loss_box_reg: 0.0443 (0.0388)  loss_objectness: 0.0014 (0.0079)  loss_rpn_box_reg: 0.0021 (0.0278)  time: 4.9485  data: 0.1113
# Epoch: [4]  [470/551]  eta: 0:06:48  lr: 0.000500  loss: 0.0877 (0.1045)  loss_classifier: 0.0343 (0.0304)  loss_box_reg: 0.0503 (0.0390)  loss_objectness: 0.0009 (0.0078)  loss_rpn_box_reg: 0.0018 (0.0272)  time: 5.0210  data: 0.1097
# Epoch: [4]  [480/551]  eta: 0:05:58  lr: 0.000500  loss: 0.0803 (0.1039)  loss_classifier: 0.0341 (0.0304)  loss_box_reg: 0.0442 (0.0390)  loss_objectness: 0.0008 (0.0077)  loss_rpn_box_reg: 0.0016 (0.0267)  time: 5.0047  data: 0.1130
# Epoch: [4]  [490/551]  eta: 0:05:07  lr: 0.000500  loss: 0.0798 (0.1034)  loss_classifier: 0.0298 (0.0304)  loss_box_reg: 0.0394 (0.0390)  loss_objectness: 0.0014 (0.0077)  loss_rpn_box_reg: 0.0013 (0.0262)  time: 4.8731  data: 0.1115
# Epoch: [4]  [500/551]  eta: 0:04:17  lr: 0.000500  loss: 0.0650 (0.1026)  loss_classifier: 0.0250 (0.0302)  loss_box_reg: 0.0314 (0.0389)  loss_objectness: 0.0040 (0.0077)  loss_rpn_box_reg: 0.0016 (0.0258)  time: 4.9047  data: 0.0998
# Epoch: [4]  [510/551]  eta: 0:03:26  lr: 0.000500  loss: 0.0650 (0.1020)  loss_classifier: 0.0240 (0.0301)  loss_box_reg: 0.0278 (0.0388)  loss_objectness: 0.0008 (0.0077)  loss_rpn_box_reg: 0.0016 (0.0254)  time: 4.8833  data: 0.1047
# Epoch: [4]  [520/551]  eta: 0:02:36  lr: 0.000500  loss: 0.0707 (0.1016)  loss_classifier: 0.0316 (0.0301)  loss_box_reg: 0.0331 (0.0389)  loss_objectness: 0.0010 (0.0076)  loss_rpn_box_reg: 0.0013 (0.0250)  time: 4.9962  data: 0.1169
# Epoch: [4]  [530/551]  eta: 0:01:45  lr: 0.000500  loss: 0.0669 (0.1011)  loss_classifier: 0.0266 (0.0301)  loss_box_reg: 0.0331 (0.0389)  loss_objectness: 0.0010 (0.0075)  loss_rpn_box_reg: 0.0013 (0.0245)  time: 5.1115  data: 0.1193
# Epoch: [4]  [540/551]  eta: 0:00:55  lr: 0.000500  loss: 0.0616 (0.1006)  loss_classifier: 0.0276 (0.0302)  loss_box_reg: 0.0304 (0.0390)  loss_objectness: 0.0009 (0.0074)  loss_rpn_box_reg: 0.0009 (0.0241)  time: 5.0686  data: 0.1210
# Epoch: [4]  [550/551]  eta: 0:00:05  lr: 0.000500  loss: 0.0603 (0.0998)  loss_classifier: 0.0276 (0.0301)  loss_box_reg: 0.0302 (0.0387)  loss_objectness: 0.0014 (0.0073)  loss_rpn_box_reg: 0.0010 (0.0237)  time: 5.0446  data: 0.1139
# Epoch: [4] Total time: 0:46:16 (5.0386 s / it)
# [W ParallelNative.cpp:230] Warning: Cannot set number of intraop threads after parallel work has started or after set_num_threads call when using native parallel backend (function set_num_threads)
# creating index...
# index created!
# Test:  [  0/272]  eta: 0:04:08  model_time: 0.8444 (0.8444)  evaluator_time: 0.0042 (0.0042)  time: 0.9126  data: 0.0639
# Test:  [100/272]  eta: 0:02:24  model_time: 0.8417 (0.7874)  evaluator_time: 0.0016 (0.0017)  time: 0.8723  data: 0.0552
# Test:  [200/272]  eta: 0:01:01  model_time: 0.8389 (0.7934)  evaluator_time: 0.0016 (0.0017)  time: 0.8734  data: 0.0566
# Test:  [271/272]  eta: 0:00:00  model_time: 0.8337 (0.7918)  evaluator_time: 0.0015 (0.0017)  time: 0.8695  data: 0.0576
# Test: Total time: 0:03:50 (0.8469 s / it)
# Averaged stats: model_time: 0.8337 (0.7918)  evaluator_time: 0.0015 (0.0017)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.813
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.934
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.914
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.813
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.228
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.853
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.853
# That's it!

# %% [markdown]
# # Plot predictions

# %%
# Inference from trained model
import matplotlib.pyplot as plt
from torchvision.utils import draw_bounding_boxes
import os

model_weights = "fasterrcnn_resnet50_fpn/Christian_5epochs/model_weights1_Masteroppgave.pt" # Husk å bytte til riktige vekter!
PATH = "/Users/magnuswiik/Documents/NTNU/5.klasse/prosjektoppgave/FishID/models/" + model_weights

root = "/Users/magnuswiik/prosjektoppgave_data/transfer_300774_files_a22bc256/Ide4_OpenClosedTransport/GP020101_rotated-annoterte-test/"

annots = list(sorted(os.listdir(os.path.join(root, "Boxes"))))
imgs = list(sorted(os.listdir(os.path.join(root, "Images"))))

model.load_state_dict(torch.load(PATH))
model.eval()

index = 0 #indices[1]

image = read_image(root + "/Images/" + imgs[index])
image = image.float() / 255.0

with torch.no_grad():
    # convert RGBA -> RGB and move to device
    x = image[:3, ...].to(device)
    predictions = model([x, ])
    pred = predictions[0]

image = (255.0 * (image - image.min()) / (image.max() - image.min())).to(torch.uint8)
image = image[:3, ...]
pred_labels = [f"salmon: {score:.3f}" for label, score in zip(pred["labels"], pred["scores"])]
pred_boxes = pred["boxes"].long()
output_image = draw_bounding_boxes(image, pred_boxes, pred_labels, colors="black", width=3, font="/System/Library/Fonts/Helvetica.ttc", font_size=30)

print(pred["scores"])

plt.figure(figsize=(12, 12))
plt.imshow(output_image.permute(1, 2, 0))
# Out:
# tensor([0.9985, 0.9975, 0.6135])

# %% [markdown]
# # Crop images based on predictions

# %%
# Crop images

from torchvision import transforms
import torch
from PIL import Image
import utils
import cv2

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

model_weights = "fasterrcnn_resnet50_fpn/model_weights2.pth" # Husk å bytte til riktige vekter!
PATH = "/Users/magnuswiik/Documents/NTNU/5.klasse/prosjektoppgave/FishID/models/" + model_weights

data_path = "/Users/magnuswiik/prosjektoppgave_data/transfer_300774_files_a22bc256/Ide4_OpenClosedTransport/GP020101_rotated-annoterte-test"
data_path_cropped = "/Users/magnuswiik/prosjektoppgave_data/transfer_300774_files_a22bc256/Ide4_OpenClosedTransport/GP020101_rotated-annoterte-test-cropped"

# our dataset has two classes only - background and person
num_classes = 2
# use our dataset and defined transformations

dataset = SalmonIndividualsDataset(data_path)

imgs = dataset.imgs

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=False,
    num_workers=0,
    collate_fn=utils.collate_fn
)

count = 0

for images, targets in data_loader:
    images = list(image for image in images)
    targets = [{k: v for k, v in t.items()} for t in targets]
    
    for i in range(len(images)):
        boxes = targets[i]['boxes'].tolist()
        labels = targets[i]['labels'].tolist()
        for j in range(len(boxes)):
            crop_image = images[i][:, int(boxes[j][1]):int(boxes[j][3]), int(boxes[j][0]):int(boxes[j][2])]
            pil_image = transforms.ToPILImage()(crop_image)
            np_image = np.array(pil_image)
            np_image = cv2.cvtColor(np_image, cv2.COLOR_RGB2BGR)
            
            fish = labels[j]
            
            cropfolder = data_path_cropped + "/fish" + str(fish) + "_" + str(count) + ".png"
            cv2.imwrite(cropfolder, np_image)
            
        count += 1
        

print("Done with cropping!")
# Out:
# Done with cropping!
